# %% [markdown]
# # Por que um professor da rede pública do DF sai da escola em que está?
# <b><hr/></b>
#
# ### Ítalo Barreto

# %% [markdown]
# ## 1. Dados
#
# ### 1.1 Micro censo
#
# Anualmente o Ministério da Educação faz um censo do ensino no Brasil.
#
# Os arquivos desse censo estão disponíveis no site do [InepData](https://inepdata.inep.gov.br/).
#
# O código para download e extração dos arquivos está em raw_data/inep_files.py
#
# O arquivo model_vars.csv - base do presente estudo - é feita pela execução arquivo MontagemDasBases.ipynb
#
# Nesse projeto irei investigar as causas do por que em 2017 cerca de 24% dos professores não estavam mais em pelo menos uma das escolas que davam aula em 2015.
#
# ### 1.2 Why?
#
# Minha motivação originou-se de ouvir uma conversa entre minha esposa e algumas amigas que são professoras concursadas da rede pública do DF. Nessa conversa todas elogiavam uma escola próxima à minha casa e quando _virou_ o ano todas elas saíram da escola.

# %% [markdown]
# ### 1.3 Verificando os pré requisitos

# %%
#Importação das bibliotecas
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import os
from glob import glob
from matplotlib import pyplot as plt
import seaborn as sns
from tqdm import tqdm
from scipy import stats
from sklearn import metrics
from tqdm import tqdm
from IPython.core.display import display, HTML
import folium
from sklearn import cluster 
from sklearn.preprocessing import MinMaxScaler
import folium
import scipy
from tabulate import tabulate

#Arquivos criados para deixar o codigo do notebook mais clean.
import modelagem
from raw_data import constantes as CONST
from educ_utils import df_inep_utils as DIU
from educ_utils import Visualizacao

# %%
# o arquivo que é pré requisito existe?
if os.path.exists(CONST.PATH_DF_CSV +'model_vars.csv'):
    print('O arquivo existe, podemos continuar.')
else:
    print('É necessário executar o código de MontagemDasBases.ipynb')
# Out:
# O arquivo existe, podemos continuar.

# %%
#Configuracao para mostrar duas casas decimais.
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ### 1.4 Dataset
#
#
# ### 1.4.1 Load do Dataset
# Agora que sabemos que o arquivo model_vars.csv existe, iremos carregá-lo, ver quantas linhas e colunas possui e ainda os tipos das colunas.

# %%
#load do arquivo
mv = pd.read_csv(f'{CONST.PATH_DF_CSV}model_vars.csv')
mv.shape
# Out:
# (8187, 85)

# %%
#head do arquivo
mv.head()
# Out:
#    CO_PESSOA_FISICA  CO_ENTIDADE  NU_QTD_TURMAS_IN_TURNO_0  \
# 0      115161698917     53001206                      0.00
# 1      115105891200     53001206                      0.00
# 2      115076010000     53001206                      7.00
# 3      117159444530     53001206                      0.00
# 4      115075882756     53001206                      6.00
#
#    NU_QTD_TURMAS_IN_TURNO_1  NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS  \
# 0                     11.00                               14.00
# 1                      6.00                               14.00
# 2                      0.00                               15.00
# 3                      6.00                               14.00
# 4                      0.00                               14.34
#
#    NU_MEDIA_TURMAS_NU_QTD_ALUNOS  NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0  \
# 0                          43.55                                     0.09
# 1                          44.50                                     0.08
# 2                          51.71                                     0.11
# 3                          48.17                                     0.14
# 4                          53.00                                     0.07
#
#    NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1  \
# 0                                     0.00
# 1                                     0.00
# 2                                     0.00
# 3                                     0.00
# 4                                     0.00
#
#    NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2  \
# 0                                     0.00
# 1                                     0.00
# 2                                     0.00
# 3                                     0.00
# 4                                     0.01
#
#    NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3  ...    NU_PROP_PSS_MULHERES_SCHL  \
# 0                                     0.12  ...                         0.55
# 1                                     0.14  ...                         0.55
# 2                                     0.16  ...                         0.55
# 3                                     0.11  ...                         0.55
# 4                                     0.14  ...                         0.55
#
#    NU_PROP_PSS_MULHERES_RSP_SCHL  NU_PROP_PSS_ABXO_12ANOS_SCHL  \
# 0                           0.16                          0.12
# 1                           0.16                          0.12
# 2                           0.16                          0.12
# 3                           0.16                          0.12
# 4                           0.16                          0.12
#
#    NU_PROP_PSS_ACIMA_65ANOS_SCHL  NU_PROP_PSS_ACIMA_90ANOS_SCHL  \
# 0                           0.13                           0.00
# 1                           0.13                           0.00
# 2                           0.13                           0.00
# 3                           0.13                           0.00
# 4                           0.13                           0.00
#
#    ROTULO_ESCOLA_SCHL  IN_SAIU_ESCOLA  NU_QTD_VEZES_PROF_ESC    LAT   LONG
# 0                   0           False                   0.00 -15.83 -47.90
# 1                   0            True                   0.20 -15.83 -47.90
# 2                   0            True                   0.80 -15.83 -47.90
# 3                   0           False                   0.20 -15.83 -47.90
# 4                   0           False                   0.80 -15.83 -47.90
#
# [5 rows x 85 columns]

# %%
display(mv.dtypes)
# Out:
# CO_PESSOA_FISICA                                int64
# CO_ENTIDADE                                     int64
# NU_QTD_TURMAS_IN_TURNO_0                      float64
# NU_QTD_TURMAS_IN_TURNO_1                      float64
# NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS            float64
# NU_MEDIA_TURMAS_NU_QTD_ALUNOS                 float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_6       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_7       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_8       float64
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9       float64
# NU_QTD_TURMAS_PROF_ESCOLA                     float64
# IN_NASCEU_DF_PROF                               int64
# IN_ESPECIALIZACAO_PROF                        float64
# TP_COR_RACA_1_PROF                              int64
# TP_COR_RACA_0_PROF                              int64
# TP_COR_RACA_3_PROF                              int64
# NU_IDADE_REFERENCIA_PROF                        int64
# CO_CLASSE_PROF                                  int64
# IN_ESGOTO_REDE_PUBLICA_SCHL                   float64
# IN_ESGOTO_FOSSA_SCHL                          float64
# IN_LABORATORIO_INFORMATICA_SCHL               float64
# IN_LABORATORIO_CIENCIAS_SCHL                  float64
# IN_SALA_ATENDIMENTO_ESPECIAL_SCHL             float64
# IN_QUADRA_ESPORTES_COBERTA_SCHL               float64
#                                                ...
# NU_COMP_ADMINISTRATIVO_SCHL                   float64
# NU_COMP_ALUNO_SCHL                            float64
# NU_FUNCIONARIOS_SCHL                          float64
# TP_AEE_SCHL                                   float64
# TP_ATIVIDADE_COMPLEMENTAR_SCHL                float64
# IN_FINAL_SEMANA_SCHL                          float64
# NU_PROP_FUNS_SALAS_UTZD_SCHL                  float64
# NU_PROP_CPU_SALAS_UTZD_SCHL                   float64
# NU_QTD_SETORES_CENSITARIOS_SCHL                 int64
# NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SCHL          float64
# NU_MEDIANA_RENDA_MEDIA_SCHL                   float64
# NU_MEDIANA_QTD_DOMICILIOS_SCHL                float64
# NU_MEDIANA_QTD_PESSOAS_SCHL                   float64
# NU_SOMA_QTD_DOMICILIOS_SCHL                     int64
# NU_SOMA_QTD_PESSOAS_SCHL                        int64
# NU_PROP_DOM_ALUGADOS_SCHL                     float64
# NU_PROP_DOM_CEDIDOS_SCHL                      float64
# NU_PROP_DOM_EM_AQUISICAO_SCHL                 float64
# NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SCHL    float64
# NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SCHL     float64
# NU_PROP_PSS_MULHERES_SCHL                     float64
# NU_PROP_PSS_MULHERES_RSP_SCHL                 float64
# NU_PROP_PSS_ABXO_12ANOS_SCHL                  float64
# NU_PROP_PSS_ACIMA_65ANOS_SCHL                 float64
# NU_PROP_PSS_ACIMA_90ANOS_SCHL                 float64
# ROTULO_ESCOLA_SCHL                              int64
# IN_SAIU_ESCOLA                                   bool
# NU_QTD_VEZES_PROF_ESC                         float64
# LAT                                           float64
# LONG                                          float64
# Length: 85, dtype: object

# %% [markdown]
# ### 1.4.2 Ajustes no Dataset
#
# O arquivo csv vem sem indexação e com a _tipagem_ _default_.

# %%
#indexa corretamente

mv.set_index(['CO_PESSOA_FISICA','CO_ENTIDADE'],inplace=True)

# %%
#ajuste na tipagem para melhorar a performance
#transformei o booleano em int para calcular as descritivas automaticamente
mv.IN_SAIU_ESCOLA = mv.IN_SAIU_ESCOLA.astype(np.int8)
mv = DIU.ajusta_colunas_int_df_inep(mv)

# %% [markdown]
# ### 1.4.3 Estrutura do Dataset
#
# Aqui vamos investigar o conteúdo e os nomes das colunas.

# %%
#mostra as 5 primeiras linhas do DataFrame
mv.head()
# Out:
#                               NU_QTD_TURMAS_IN_TURNO_0  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                         0.00
# 115105891200     53001206                         0.00
# 115076010000     53001206                         7.00
# 117159444530     53001206                         0.00
# 115075882756     53001206                         6.00
#
#                               NU_QTD_TURMAS_IN_TURNO_1  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                        11.00
# 115105891200     53001206                         6.00
# 115076010000     53001206                         0.00
# 117159444530     53001206                         6.00
# 115075882756     53001206                         0.00
#
#                               NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                                  14.00
# 115105891200     53001206                                  14.00
# 115076010000     53001206                                  15.00
# 117159444530     53001206                                  14.00
# 115075882756     53001206                                  14.34
#
#                               NU_MEDIA_TURMAS_NU_QTD_ALUNOS  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                             43.53
# 115105891200     53001206                             44.50
# 115076010000     53001206                             51.72
# 117159444530     53001206                             48.16
# 115075882756     53001206                             53.00
#
#                               NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                                        0.09
# 115105891200     53001206                                        0.08
# 115076010000     53001206                                        0.11
# 117159444530     53001206                                        0.14
# 115075882756     53001206                                        0.07
#
#                               NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                                        0.00
# 115105891200     53001206                                        0.00
# 115076010000     53001206                                        0.00
# 117159444530     53001206                                        0.00
# 115075882756     53001206                                        0.00
#
#                               NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                                        0.00
# 115105891200     53001206                                        0.00
# 115076010000     53001206                                        0.00
# 117159444530     53001206                                        0.00
# 115075882756     53001206                                        0.01
#
#                               NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                                        0.12
# 115105891200     53001206                                        0.14
# 115076010000     53001206                                        0.16
# 117159444530     53001206                                        0.11
# 115075882756     53001206                                        0.14
#
#                               NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                                        0.00
# 115105891200     53001206                                        0.00
# 115076010000     53001206                                        0.00
# 117159444530     53001206                                        0.00
# 115075882756     53001206                                        0.00
#
#                               NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5  ...    \
# CO_PESSOA_FISICA CO_ENTIDADE                                           ...
# 115161698917     53001206                                        0.00  ...
# 115105891200     53001206                                        0.00  ...
# 115076010000     53001206                                        0.00  ...
# 117159444530     53001206                                        0.00  ...
# 115075882756     53001206                                        0.00  ...
#
#                               NU_PROP_PSS_MULHERES_SCHL  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                          0.55
# 115105891200     53001206                          0.55
# 115076010000     53001206                          0.55
# 117159444530     53001206                          0.55
# 115075882756     53001206                          0.55
#
#                               NU_PROP_PSS_MULHERES_RSP_SCHL  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                              0.16
# 115105891200     53001206                              0.16
# 115076010000     53001206                              0.16
# 117159444530     53001206                              0.16
# 115075882756     53001206                              0.16
#
#                               NU_PROP_PSS_ABXO_12ANOS_SCHL  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                             0.12
# 115105891200     53001206                             0.12
# 115076010000     53001206                             0.12
# 117159444530     53001206                             0.12
# 115075882756     53001206                             0.12
#
#                               NU_PROP_PSS_ACIMA_65ANOS_SCHL  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                              0.13
# 115105891200     53001206                              0.13
# 115076010000     53001206                              0.13
# 117159444530     53001206                              0.13
# 115075882756     53001206                              0.13
#
#                               NU_PROP_PSS_ACIMA_90ANOS_SCHL  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                              0.00
# 115105891200     53001206                              0.00
# 115076010000     53001206                              0.00
# 117159444530     53001206                              0.00
# 115075882756     53001206                              0.00
#
#                               ROTULO_ESCOLA_SCHL  IN_SAIU_ESCOLA  \
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                      0               0
# 115105891200     53001206                      0               1
# 115076010000     53001206                      0               1
# 117159444530     53001206                      0               0
# 115075882756     53001206                      0               0
#
#                               NU_QTD_VEZES_PROF_ESC    LAT   LONG
# CO_PESSOA_FISICA CO_ENTIDADE
# 115161698917     53001206                      0.00 -15.83 -47.91
# 115105891200     53001206                      0.20 -15.83 -47.91
# 115076010000     53001206                      0.80 -15.83 -47.91
# 117159444530     53001206                      0.20 -15.83 -47.91
# 115075882756     53001206                      0.80 -15.83 -47.91
#
# [5 rows x 83 columns]

# %%
#Dá uma visão geral das colunas do Dataset, fiz um transpose para "ver melhor" os dados
mv.describe().T
# Out:
#                                              count    mean      std       min  \
# NU_QTD_TURMAS_IN_TURNO_0                   8183.00    2.27     3.80      0.00
# NU_QTD_TURMAS_IN_TURNO_1                   8183.00    1.61     3.24      0.00
# NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS         8183.00     inf     4.27      0.00
# NU_MEDIA_TURMAS_NU_QTD_ALUNOS              8183.00     inf      inf      1.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0    8183.00    0.11     0.13      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1    8183.00    0.16     0.24      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2    8183.00    0.10     0.24      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3    8183.00    0.06     0.08      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4    8183.00    0.12     0.21      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5    8183.00    0.08     0.15      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_6    8183.00    0.12     0.26      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_7    8183.00    0.09     0.15      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_8    8183.00    0.08     0.15      0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9    8183.00    0.08     0.12      0.00
# NU_QTD_TURMAS_PROF_ESCOLA                  8183.00    4.58     4.32      1.00
# IN_NASCEU_DF_PROF                          8187.00    0.50     0.50      0.00
# IN_ESPECIALIZACAO_PROF                     8187.00    0.54     0.50      0.00
# TP_COR_RACA_1_PROF                         8187.00    0.31     0.46      0.00
# TP_COR_RACA_0_PROF                         8187.00    0.34     0.47      0.00
# TP_COR_RACA_3_PROF                         8187.00    0.30     0.46      0.00
# NU_IDADE_REFERENCIA_PROF                   8187.00   43.01     7.59     24.00
# CO_CLASSE_PROF                             8187.00    3.37     2.33      0.00
# IN_ESGOTO_REDE_PUBLICA_SCHL                8187.00    0.94     0.24      0.00
# IN_ESGOTO_FOSSA_SCHL                       8187.00    0.06     0.24      0.00
# IN_LABORATORIO_INFORMATICA_SCHL            8187.00    0.90     0.30      0.00
# IN_LABORATORIO_CIENCIAS_SCHL               8187.00    0.32     0.47      0.00
# IN_SALA_ATENDIMENTO_ESPECIAL_SCHL          8187.00    0.84     0.36      0.00
# IN_QUADRA_ESPORTES_COBERTA_SCHL            8187.00    0.35     0.48      0.00
# IN_QUADRA_ESPORTES_DESCOBERTA_SCHL         8187.00    0.57     0.49      0.00
# IN_QUADRA_ESPORTES_SCHL                    8187.00    0.82     0.39      0.00
# ...                                            ...     ...      ...       ...
# NU_COMP_ADMINISTRATIVO_SCHL                8187.00    5.95     7.12      0.00
# NU_COMP_ALUNO_SCHL                         8187.00     inf    13.83      0.00
# NU_FUNCIONARIOS_SCHL                       8187.00     inf      inf     10.00
# TP_AEE_SCHL                                8187.00    0.70     0.46      0.00
# TP_ATIVIDADE_COMPLEMENTAR_SCHL             8187.00    0.40     0.49      0.00
# IN_FINAL_SEMANA_SCHL                       8187.00    0.24     0.43      0.00
# NU_PROP_FUNS_SALAS_UTZD_SCHL               8187.00    5.86     1.77      2.00
# NU_PROP_CPU_SALAS_UTZD_SCHL                8187.00    1.94     2.31      0.00
# NU_QTD_SETORES_CENSITARIOS_SCHL            8187.00  174.25    99.96      1.00
# NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SCHL       8187.00    1.54     0.25      1.04
# NU_MEDIANA_RENDA_MEDIA_SCHL                8187.00     inf      inf   1101.00
# NU_MEDIANA_QTD_DOMICILIOS_SCHL             8187.00     inf    17.95     34.00
# NU_MEDIANA_QTD_PESSOAS_SCHL                8187.00     inf      inf    105.00
# NU_SOMA_QTD_DOMICILIOS_SCHL                8187.00 4115.38 21029.88 -32721.00
# NU_SOMA_QTD_PESSOAS_SCHL                   8187.00  953.74 17493.29 -31623.00
# NU_PROP_DOM_ALUGADOS_SCHL                  8187.00    0.32     0.07      0.00
# NU_PROP_DOM_CEDIDOS_SCHL                   8187.00    0.10     0.06      0.04
# NU_PROP_DOM_EM_AQUISICAO_SCHL              8187.00    0.05     0.03      0.00
# NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SCHL 8187.00    0.15     0.21      0.00
# NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SCHL  8187.00    0.41     0.20      0.02
# NU_PROP_PSS_MULHERES_SCHL                  8187.00    0.52     0.02      0.40
# NU_PROP_PSS_MULHERES_RSP_SCHL              8187.00    0.13     0.02      0.02
# NU_PROP_PSS_ABXO_12ANOS_SCHL               8187.00    0.20     0.04      0.11
# NU_PROP_PSS_ACIMA_65ANOS_SCHL              8187.00    0.05     0.03      0.01
# NU_PROP_PSS_ACIMA_90ANOS_SCHL              8187.00    0.00     0.00      0.00
# ROTULO_ESCOLA_SCHL                         8187.00   20.27    14.28      0.00
# IN_SAIU_ESCOLA                             8187.00    0.24     0.43      0.00
# NU_QTD_VEZES_PROF_ESC                      8187.00    0.51     0.34      0.00
# LAT                                        8187.00    -inf     0.10    -16.05
# LONG                                       8187.00    -inf     0.14    -48.25
#
#                                                  25%      50%      75%  \
# NU_QTD_TURMAS_IN_TURNO_0                        0.00     1.00     2.00
# NU_QTD_TURMAS_IN_TURNO_1                        0.00     0.00     1.00
# NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS              7.00     8.00    10.00
# NU_MEDIA_TURMAS_NU_QTD_ALUNOS                  22.00    31.61    41.75
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0         0.00     0.07     0.17
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1         0.00     0.00     0.31
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2         0.00     0.00     0.01
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3         0.00     0.00     0.13
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4         0.00     0.00     0.15
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5         0.00     0.00     0.05
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_6         0.00     0.00     0.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_7         0.00     0.00     0.15
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_8         0.00     0.00     0.03
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9         0.00     0.04     0.11
# NU_QTD_TURMAS_PROF_ESCOLA                       1.00     3.00     7.00
# IN_NASCEU_DF_PROF                               0.00     1.00     1.00
# IN_ESPECIALIZACAO_PROF                          0.00     1.00     1.00
# TP_COR_RACA_1_PROF                              0.00     0.00     1.00
# TP_COR_RACA_0_PROF                              0.00     0.00     1.00
# TP_COR_RACA_3_PROF                              0.00     0.00     1.00
# NU_IDADE_REFERENCIA_PROF                       38.00    43.00    48.00
# CO_CLASSE_PROF                                  1.00     3.00     5.00
# IN_ESGOTO_REDE_PUBLICA_SCHL                     1.00     1.00     1.00
# IN_ESGOTO_FOSSA_SCHL                            0.00     0.00     0.00
# IN_LABORATORIO_INFORMATICA_SCHL                 1.00     1.00     1.00
# IN_LABORATORIO_CIENCIAS_SCHL                    0.00     0.00     1.00
# IN_SALA_ATENDIMENTO_ESPECIAL_SCHL               1.00     1.00     1.00
# IN_QUADRA_ESPORTES_COBERTA_SCHL                 0.00     0.00     1.00
# IN_QUADRA_ESPORTES_DESCOBERTA_SCHL              0.00     1.00     1.00
# IN_QUADRA_ESPORTES_SCHL                         1.00     1.00     1.00
# ...                                              ...      ...      ...
# NU_COMP_ADMINISTRATIVO_SCHL                     2.00     5.00     7.00
# NU_COMP_ALUNO_SCHL                              9.00    17.00    27.00
# NU_FUNCIONARIOS_SCHL                           70.00    96.00   125.00
# TP_AEE_SCHL                                     0.00     1.00     1.00
# TP_ATIVIDADE_COMPLEMENTAR_SCHL                  0.00     0.00     1.00
# IN_FINAL_SEMANA_SCHL                            0.00     0.00     0.00
# NU_PROP_FUNS_SALAS_UTZD_SCHL                    4.64     5.60     6.80
# NU_PROP_CPU_SALAS_UTZD_SCHL                     1.14     1.67     2.33
# NU_QTD_SETORES_CENSITARIOS_SCHL               100.00   159.00   247.00
# NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SCHL            1.43     1.52     1.65
# NU_MEDIANA_RENDA_MEDIA_SCHL                  1897.00  2356.00  4500.00
# NU_MEDIANA_QTD_DOMICILIOS_SCHL                173.00   182.00   191.00
# NU_MEDIANA_QTD_PESSOAS_SCHL                   563.00   625.00   669.50
# NU_SOMA_QTD_DOMICILIOS_SCHL                -12460.00 11028.00 20820.00
# NU_SOMA_QTD_PESSOAS_SCHL                   -11865.00  1910.00 13985.00
# NU_PROP_DOM_ALUGADOS_SCHL                       0.28     0.33     0.36
# NU_PROP_DOM_CEDIDOS_SCHL                        0.08     0.10     0.11
# NU_PROP_DOM_EM_AQUISICAO_SCHL                   0.02     0.04     0.06
# NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SCHL      0.02     0.05     0.19
# NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SCHL       0.22     0.47     0.56
# NU_PROP_PSS_MULHERES_SCHL                       0.51     0.51     0.53
# NU_PROP_PSS_MULHERES_RSP_SCHL                   0.13     0.13     0.14
# NU_PROP_PSS_ABXO_12ANOS_SCHL                    0.17     0.21     0.22
# NU_PROP_PSS_ACIMA_65ANOS_SCHL                   0.03     0.05     0.07
# NU_PROP_PSS_ACIMA_90ANOS_SCHL                   0.00     0.00     0.00
# ROTULO_ESCOLA_SCHL                              1.00    30.00    31.00
# IN_SAIU_ESCOLA                                  0.00     0.00     0.00
# NU_QTD_VEZES_PROF_ESC                           0.20     0.40     0.80
# LAT                                           -15.89   -15.83   -15.80
# LONG                                          -48.09   -48.06   -47.91
#
#                                                 max
# NU_QTD_TURMAS_IN_TURNO_0                      28.00
# NU_QTD_TURMAS_IN_TURNO_1                      26.00
# NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS            16.00
# NU_MEDIA_TURMAS_NU_QTD_ALUNOS                910.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0        1.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1        1.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2        1.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3        0.50
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4        1.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5        0.88
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_6        0.89
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_7        1.00
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_8        0.75
# NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9        1.00
# NU_QTD_TURMAS_PROF_ESCOLA                     38.00
# IN_NASCEU_DF_PROF                              1.00
# IN_ESPECIALIZACAO_PROF                         1.00
# TP_COR_RACA_1_PROF                             1.00
# TP_COR_RACA_0_PROF                             1.00
# TP_COR_RACA_3_PROF                             1.00
# NU_IDADE_REFERENCIA_PROF                      69.00
# CO_CLASSE_PROF                                 7.00
# IN_ESGOTO_REDE_PUBLICA_SCHL                    1.00
# IN_ESGOTO_FOSSA_SCHL                           1.00
# IN_LABORATORIO_INFORMATICA_SCHL                1.00
# IN_LABORATORIO_CIENCIAS_SCHL                   1.00
# IN_SALA_ATENDIMENTO_ESPECIAL_SCHL              1.00
# IN_QUADRA_ESPORTES_COBERTA_SCHL                1.00
# IN_QUADRA_ESPORTES_DESCOBERTA_SCHL             1.00
# IN_QUADRA_ESPORTES_SCHL                        1.00
# ...                                             ...
# NU_COMP_ADMINISTRATIVO_SCHL                   53.00
# NU_COMP_ALUNO_SCHL                            80.00
# NU_FUNCIONARIOS_SCHL                         392.00
# TP_AEE_SCHL                                    1.00
# TP_ATIVIDADE_COMPLEMENTAR_SCHL                 1.00
# IN_FINAL_SEMANA_SCHL                           1.00
# NU_PROP_FUNS_SALAS_UTZD_SCHL                  17.00
# NU_PROP_CPU_SALAS_UTZD_SCHL                   60.75
# NU_QTD_SETORES_CENSITARIOS_SCHL              432.00
# NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SCHL           4.85
# NU_MEDIANA_RENDA_MEDIA_SCHL                14048.00
# NU_MEDIANA_QTD_DOMICILIOS_SCHL               215.50
# NU_MEDIANA_QTD_PESSOAS_SCHL                  769.00
# NU_SOMA_QTD_DOMICILIOS_SCHL                32697.00
# NU_SOMA_QTD_PESSOAS_SCHL                   32356.00
# NU_PROP_DOM_ALUGADOS_SCHL                      0.45
# NU_PROP_DOM_CEDIDOS_SCHL                       1.00
# NU_PROP_DOM_EM_AQUISICAO_SCHL                  0.17
# NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SCHL     0.71
# NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SCHL      0.82
# NU_PROP_PSS_MULHERES_SCHL                      0.55
# NU_PROP_PSS_MULHERES_RSP_SCHL                  0.18
# NU_PROP_PSS_ABXO_12ANOS_SCHL                   0.30
# NU_PROP_PSS_ACIMA_65ANOS_SCHL                  0.15
# NU_PROP_PSS_ACIMA_90ANOS_SCHL                  0.01
# ROTULO_ESCOLA_SCHL                            31.00
# IN_SAIU_ESCOLA                                 1.00
# NU_QTD_VEZES_PROF_ESC                          1.00
# LAT                                          -15.58
# LONG                                         -47.38
#
# [83 rows x 8 columns]

# %% [markdown]
# #### Colunas do Dataframe
#
# Para a nomenclatura das colunas segui o mesmo padrão do Inep, onde os prefixos:
#
# * NU: representam colunas numéricas (exceção LAT e LONG).
# * IN: representam indicadores (1 - Sim, 0 - Não).
# * CO: código (lista de valores que significam uma string).
# * TP: tipo (também lista de valores, a exceção é TP_COR_RACA_X_PROF que é um indicador).
#
# Para os sufixos adotei o padrão:
# * PROF: dado do professor.
# * SCHL: dado da escola (exceção dos campos LAT e LONG).
#
# #### Nomes das colunas
#
# - NU_QTD_TURMAS_IN_TURNO_0: quantidade de turmas no matutino.
# - NU_QTD_TURMAS_IN_TURNO_1: quantidade de turmas no vespertino.
# - NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS: média da quantidade de disciplinas que cada uma das turmas que o professor dá aula naquela escola possui.
# - NU_MEDIA_TURMAS_NU_QTD_ALUNOS: média da quantidade de alunos em cada uma das turmas que o professor dá aula naquela escola.
# ##### Média nas turmas em que o professor dava aula na escola da"razão entre o número de alunos de um determinado cluster e o total de alunos da turma". O significado dos cluters (rótulos) está bem descrito no arquivo de montagem do dataset.
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_6:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_7:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_8:
# - NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9:
# <br/><br/>
# - NU_QTD_TURMAS_PROF_ESCOLA: quantidade de turmas que o professor ministra aulas.
# - IN_NASCEU_DF_PROF: indicador se o professor nasceu no DF.
# - IN_ESPECIALIZACAO_PROF: indicador se o professor possui alguma especialização.
#
# - TP_COR_RACA_1_PROF: indicador se a COR/RAÇA do professor é branca.
# - TP_COR_RACA_0_PROF: indicador se a COR/RAÇA do professor não informada.
# - TP_COR_RACA_3_PROF: indicador se a COR/RAÇA do professor é parda.
# - NU_IDADE_REFERENCIA_PROF: idade do professor ao final do ano do censo.
# - CO_CLASSE_PROF: o cluster que o professor foi colocado, os clusters estão bem descritos no arquivo de montagem da base.
# - IN_ESGOTO_REDE_PUBLICA_SCHL: indicador se o esgoto da escola é coletado pela rede pública.
# - IN_ESGOTO_FOSSA_SCHL: inicador se o esgoto da escola é coletado em fossas.
# - IN_LABORATORIO_INFORMATICA_SCHL: indicador se a escola possui laboratório de informática.
# - IN_LABORATORIO_CIENCIAS_SCHL: indicador se a escola possui labiratório de ciências.
# - IN_SALA_ATENDIMENTO_ESPECIAL_SCHL: indicador se a escola possui sala de atendimento especial.
# - IN_QUADRA_ESPORTES_COBERTA_SCHL: indicador se a escola possui quadra de esportes coberta.
# - IN_QUADRA_ESPORTES_DESCOBERTA_SCHL: indicador se a escola possui quadra de esportes descoberta.
# - IN_QUADRA_ESPORTES_SCHL: indicador se a escola possui quadra de esportes.
# - IN_BIBLIOTECA_SCHL: indicador se a escola possui biblioteca.
# - IN_SALA_LEITURA_SCHL: indicador se a escola possui sala de leitura.
# - IN_BIBLIOTECA_SALA_LEITURA_SCHL: indicador se a escola possui biblioteca e sala de leitura.
# - IN_PARQUE_INFANTIL_SCHL: indicador se a escola possui parque infantil.
# - IN_BANHEIRO_EI_SCHL: indicador se a escola possui banheiro especial.
# - IN_BANHEIRO_PNE_SCHL: indicador se a escola possui banheiro para Portadores de Necessidades Especiais (PNE).
# - IN_DEPENDENCIAS_PNE_SCHL: indicador se a escola possui dependências para PNE.
# - IN_BANHEIRO_CHUVEIRO_SCHL: indicador se a escola possui chuveiro.
# - IN_REFEITORIO_SCHL: indicador se a escola possui refeitório.
# - IN_DESPENSA_SCHL: indicador se a escola possui despensa.
# - IN_ALMOXARIFADO_SCHL: indicador se a escola possui almoxarifado.
# - IN_AUDITORIO_SCHL: indicador se a escola possui auditório.
# - IN_PATIO_COBERTO_SCHL: indicador se a escola possui pátio coberto.
# - IN_PATIO_DESCOBERTO_SCHL: indicador se a escola possui pátio descoberto.
# - IN_AREA_VERDE_SCHL: indicador se a escola possui área verde.
# - NU_SALAS_EXISTENTES_SCHL: quantidade de salas existentes na escola.
# - IN_EQUIP_VIDEOCASSETE_SCHL: indicador se a escola possui equipamento de vídeo cassete.
# - IN_EQUIP_PARABOLICA_SCHL: indicador se a escola possui antena parabólica.
# - IN_EQUIP_RETROPROJETOR_SCHL: indicador se a escola possui equipamento de retroprojetor.
# - IN_EQUIP_IMPRESSORA_MULT_SCHL: indicador se a escola possui impressora multifuncional.
# - IN_EQUIP_FAX_SCHL: indicador se a escola possui aparelho de fax.
# - IN_EQUIP_FOTO_SCHL: indicador se a escola possui fotocopiadora.
# - NU_COMPUTADOR_SCHL: quantidade de computadores na escola.
# - NU_COMP_ADMINISTRATIVO_SCHL: quantidade de computadores para fins administrativos.
# - NU_COMP_ALUNO_SCHL: quantidade de computadores para uso em aula.
# - NU_FUNCIONARIOS_SCHL: quantidade de funcionários da escola.
# - TP_AEE_SCHL: indicador se a escola oferece Atendimento Educacional Especializado (AEE).
# - TP_ATIVIDADE_COMPLEMENTAR_SCHL: indicador se a escola oferece Atividade Complementar.
# - IN_FINAL_SEMANA_SCHL: indicador se há aula de final de semana na escola.
# - NU_PROP_FUNS_SALAS_UTZD_SCHL: razão entre quantidade de funcionários na escola e a quantidade de salas utilizadas na escola.
# - NU_PROP_CPU_SALAS_UTZD_SCHL: razão entre quantidade de computadores na escola e a quantidade de salas utilizadas na escola.
#
# ##### Dados obtidos do censo 2010 do IBGE.
# - NU_QTD_SETORES_CENSITARIOS_SCHL: quantidade de setores censitários (IBGE) num raio de 2,5km ou a metade da distância da escola mais próxima (o que for maior).
# - NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SCHL: média das distâncias, em km, entre o centróide do setor censitário e a escola.
# - NU_MEDIANA_RENDA_MEDIA_SCHL: mediana da renda média dos domicílios dos setores censitários ao redor da escola.
# - NU_MEDIANA_QTD_DOMICILIOS_SCHL: mediana da quantidade de domicílios nos setores censitários ao redor da escola.
# - NU_MEDIANA_QTD_PESSOAS_SCHL: mediana da quantidade de pessoas nos setores censitários ao redor da escola.
# - NU_SOMA_QTD_DOMICILIOS_SCHL: quantidade total de domícilios ao redor da escola.
# - NU_SOMA_QTD_PESSOAS_SCHL: população ao redor da escola.
# - NU_PROP_DOM_ALUGADOS_SCHL: razão entre quantidade de domicílios alugados e a quantidade total de domicílios ao redor da escola.
# - NU_PROP_DOM_CEDIDOS_SCHL: razão entre quantidade de domicílios cedidos e a quantidade total de domicílios ao redor da escola.
# - NU_PROP_DOM_EM_AQUISICAO_SCHL: razão entre quantidade de domicílios em aquisição (financiados) e a quantidade total de domicílios ao redor da escola.
# - NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SCHL: razão entre quantidade de domicílios cuja renda _per capita_ é acima de 5 salários mínimos e a quantidade total de domicílios ao redor da escola.
# - NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SCHL:  razão entre quantidade de domicílios cuja renda _per capita_ é abaixo de 1 salário mínimo e a quantidade total de domicílios ao redor da escola.
# - NU_PROP_PSS_MULHERES_SCHL: razão entre a quantidade de mulheres e a população ao redor da escola.
# - NU_PROP_PSS_MULHERES_RSP_SCHL: razão entre a quantidade de mulheres responsáveis pelo domicílio e a população ao redor da escola.
# - NU_PROP_PSS_ABXO_12ANOS_SCHL: razão entre a quantidade de pessoas abaixo dos 12 anos (crianças) e a população ao redor da escola.
# - NU_PROP_PSS_ACIMA_65ANOS_SCHL: razão entre a quantidade de pessoas acima de 65 anos e a população ao redor da escola.
# - NU_PROP_PSS_ACIMA_90ANOS_SCHL: razão entre a quantidade de pessoas acima de 90 anos e a população ao redor da escola.
# <br/><br/>
# - ROTULO_ESCOLA_SCHL: cluster a que pertence a escola.
# - IN_SAIU_ESCOLA: indicador se o professor não estava naquela escola em 2017.
# - NU_QTD_VEZES_PROF_ESC: número de vezes que o registro professor/escola apareceu no censo desde 2007.
# - LAT: latitude em que se encontra a escola.
# - LONG: longitude em que se encontra a escola.
#
# Aqui já vemos que são 8.187 professores/turmas e que em 2017 cerca de 24% dos professores saíram de alguma escola que estavam em 2015.

# %%
#vamos renomear as colunas que são exceções ao padrão de nomenclatura.
mv.rename(columns={'TP_COR_RACA_1_PROF' : 'IN_TP_COR_RACA_BRANCA_PROF',
                   'TP_COR_RACA_0_PROF' : 'IN_TP_COR_RACA_NAO_INFMD_PROF' ,
                   'TP_COR_RACA_3_PROF' : 'IN_TP_COR_RACA_PARDA_PROF' ,
                   'TP_AEE_SCHL' : 'IN_AEE_SCHL',
                   'TP_ATIVIDADE_COMPLEMENTAR_SCHL' : 'IN_ATIVIDADE_COMPLEMENTAR_SCHL',
                   'LAT': 'NU_LATITUDE_SCHL',
                   'LONG' : 'NU_LONGITUDE_SCHL',
                   'CO_CLASSE_PROF' : 'CO_CLUSTER_PROF',
                   'ROTULO_ESCOLA_SCHL' : 'CO_CLUSTER_SCHL'},inplace=True)

#Cria um padrão de nomenclatura para as colunas com dados dos setores censitários.
colunas_setores_censitarios = [
    'NU_QTD_SETORES_CENSITARIOS_SCHL',
    'NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SCHL',
    'NU_MEDIANA_RENDA_MEDIA_SCHL',
    'NU_MEDIANA_QTD_DOMICILIOS_SCHL',
    'NU_MEDIANA_QTD_PESSOAS_SCHL',
    'NU_SOMA_QTD_DOMICILIOS_SCHL',
    'NU_SOMA_QTD_PESSOAS_SCHL',
    'NU_PROP_DOM_ALUGADOS_SCHL',
    'NU_PROP_DOM_CEDIDOS_SCHL',
    'NU_PROP_DOM_EM_AQUISICAO_SCHL',
    'NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SCHL',
    'NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SCHL',
    'NU_PROP_PSS_MULHERES_SCHL',
    'NU_PROP_PSS_MULHERES_RSP_SCHL',
    'NU_PROP_PSS_ABXO_12ANOS_SCHL',
    'NU_PROP_PSS_ACIMA_65ANOS_SCHL',
    'NU_PROP_PSS_ACIMA_90ANOS_SCHL'
    ]
mv.rename(columns={col : col[:-5] + '_SC' + col[-5:] for col in colunas_setores_censitarios},inplace=True)

# %%
#Os códigos dos clusters são categorias
for c in mv.columns:
    if c.startswith('CO_'):
        mv[c] = pd.Categorical(mv[c])

# %% [markdown]
# ## 2. Gráficos e análises

# %% [markdown]
# ### 2.1 Gráficos univariados
#
# #### 2.1.1 Professores

# %%
#As colunas com final _PROF são exclusivas dos professores.
prof = mv.reset_index().drop('CO_ENTIDADE',axis=1)[
            [c for c in mv.columns if c.endswith('_PROF')] +['CO_PESSOA_FISICA']]\
            .drop_duplicates()\
            .set_index('CO_PESSOA_FISICA')
display(prof.shape)
display(prof.head())
# Out:
# (7650, 7)
#                   IN_NASCEU_DF_PROF  IN_ESPECIALIZACAO_PROF  \
# CO_PESSOA_FISICA
# 115161698917                      1                    0.00
# 115105891200                      0                    0.00
# 115076010000                      0                    0.00
# 117159444530                      0                    1.00
# 115075882756                      1                    1.00
#
#                   IN_TP_COR_RACA_BRANCA_PROF  IN_TP_COR_RACA_NAO_INFMD_PROF  \
# CO_PESSOA_FISICA
# 115161698917                               0                              1
# 115105891200                               0                              1
# 115076010000                               1                              0
# 117159444530                               1                              0
# 115075882756                               0                              0
#
#                   IN_TP_COR_RACA_PARDA_PROF  NU_IDADE_REFERENCIA_PROF  \
# CO_PESSOA_FISICA
# 115161698917                              0                        41
# 115105891200                              0                        45
# 115076010000                              0                        51
# 117159444530                              0                        51
# 115075882756                              1                        49
#
#                  CO_CLUSTER_PROF
# CO_PESSOA_FISICA
# 115161698917                   6
# 115105891200                   3
# 115076010000                   5
# 117159444530                   5
# 115075882756                   7

# %%
#Como são muitas variáveis iremos fazer uma visualização padrão
#a partir dessas informações já podemos fazer algumas observações interessantes.
Visualizacao.explora_df(prof)
# Out:
# <h2>1. IN_NASCEU_DF_PROF</h2>
# '0.0% de registros nulos'
# 'Variância: 0.25002514746256715'
#     qtd   pc
# 1  3846 0.50
# 0  3804 0.50
# <hr/>
# <h2>2. IN_ESPECIALIZACAO_PROF</h2>
# '0.0% de registros nulos'
# 'Variância: 0.247802734375'
#        qtd   pc
# 1.00  4188 0.55
# 0.00  3462 0.45
# <hr/>
# <h2>3. IN_TP_COR_RACA_BRANCA_PROF</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2139528000157225'
#     qtd   pc
# 0  5278 0.69
# 1  2372 0.31
# <hr/>
# <h2>4. IN_TP_COR_RACA_NAO_INFMD_PROF</h2>
# '0.0% de registros nulos'
# 'Variância: 0.22354325440465111'
#     qtd   pc
# 0  5070 0.66
# 1  2580 0.34
# <hr/>
# <h2>5. IN_TP_COR_RACA_PARDA_PROF</h2>
# '0.0% de registros nulos'
# 'Variância: 0.20987041750940152'
#     qtd   pc
# 0  5358 0.70
# 1  2292 0.30
# <hr/>
# <h2>6. NU_IDADE_REFERENCIA_PROF</h2>
# '0.0% de registros nulos'
# 'Variância: 57.03131531568482'
# count   7650.00
# mean      42.96
# std        7.55
# min       24.00
# 25%       38.00
# 50%       43.00
# 75%       48.00
# max       69.00
# Name: NU_IDADE_REFERENCIA_PROF, dtype: float64
# <hr/>
# <h2>7. CO_CLUSTER_PROF</h2>
# '0.0% de registros nulos'
# Não foi possível calcular a variância.
#     qtd   pc
# 5  1213 0.16
# 1  1159 0.15
# 0  1125 0.15
# 7   891 0.12
# 4   880 0.12
# 3   825 0.11
# 6   794 0.10
# 2   763 0.10
# <hr/>

# %%
#ktest para testar a normalidade das idades.
x = prof.NU_IDADE_REFERENCIA_PROF.values
ks_results = scipy.stats.kstest(x, cdf='norm')

matrix_ks = [
    ['', 'DF', 'Test Statistic', 'p-value'],
    ['Sample Data', len(x) - 1, ks_results[0], ks_results[1]]
]

display(HTML(tabulate(matrix_ks, tablefmt="html")))
# Out:
# <table>
# <tbody>
# <tr><td>           </td><td>DF  </td><td>Test Statistic</td><td>p-value</td></tr>
# <tr><td>Sample Data</td><td>7649</td><td>1.0           </td><td>0.0    </td></tr>
# </tbody>
# </table>

# %% [markdown]
# #### Algumas observações interessantes:
#
# - Os professores/escola são menos jovens do que eu esperava. Mínimo 24, percentil 25 é 38 e média e mediana de 43, a distribuição é praticamente normal.
# - Somente 5% se consideram da COR/RACA preta (5% que não são brancos, nem pardos, nem não informado).
# - 50% dos professores não nasceram no DF.
# - Quase a metade não possui especialização.

# %% [markdown]
# #### 2.1.2 Escolas

# %%
#criação de um dataframe com os dados das escolas
schl = mv.reset_index().drop('CO_PESSOA_FISICA',axis=1)[
            [c for c in mv.columns if c.endswith('_SCHL')] +['CO_ENTIDADE']]\
            .drop_duplicates()\
            .set_index('CO_ENTIDADE')
#tamanho da tabela
display(schl.shape)
#lista as 5 primeiras linhas
display(schl.head())
#mostra todas as colunas e os tipos
HTML(tabulate([[col,schl[col].dtype] for col in schl.columns],tablefmt='html'))
# Out:
# (498, 59)
#              IN_ESGOTO_REDE_PUBLICA_SCHL  IN_ESGOTO_FOSSA_SCHL  \
# CO_ENTIDADE
# 53001206                            1.00                  0.00
# 53011988                            1.00                  0.00
# 53068181                            1.00                  0.00
# 53013980                            1.00                  0.00
# 53001893                            1.00                  0.00
#
#              IN_LABORATORIO_INFORMATICA_SCHL  IN_LABORATORIO_CIENCIAS_SCHL  \
# CO_ENTIDADE
# 53001206                                1.00                          0.00
# 53011988                                1.00                          0.00
# 53068181                                0.00                          0.00
# 53013980                                0.00                          0.00
# 53001893                                1.00                          0.00
#
#              IN_SALA_ATENDIMENTO_ESPECIAL_SCHL  \
# CO_ENTIDADE
# 53001206                                  1.00
# 53011988                                  1.00
# 53068181                                  1.00
# 53013980                                  1.00
# 53001893                                  0.00
#
#              IN_QUADRA_ESPORTES_COBERTA_SCHL  \
# CO_ENTIDADE
# 53001206                                0.00
# 53011988                                1.00
# 53068181                                0.00
# 53013980                                0.00
# 53001893                                0.00
#
#              IN_QUADRA_ESPORTES_DESCOBERTA_SCHL  IN_QUADRA_ESPORTES_SCHL  \
# CO_ENTIDADE
# 53001206                                   1.00                     1.00
# 53011988                                   0.00                     1.00
# 53068181                                   1.00                     1.00
# 53013980                                   0.00                     0.00
# 53001893                                   1.00                     1.00
#
#              IN_BIBLIOTECA_SCHL  IN_SALA_LEITURA_SCHL        ...          \
# CO_ENTIDADE                                                  ...
# 53001206                   1.00                  0.00        ...
# 53011988                   1.00                  1.00        ...
# 53068181                   1.00                  1.00        ...
# 53013980                   0.00                  0.00        ...
# 53001893                   1.00                  1.00        ...
#
#              NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SC_SCHL  \
# CO_ENTIDADE
# 53001206                                              0.66
# 53011988                                              0.04
# 53068181                                              0.02
# 53013980                                              0.70
# 53001893                                              0.69
#
#              NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SC_SCHL  \
# CO_ENTIDADE
# 53001206                                             0.04
# 53011988                                             0.56
# 53068181                                             0.60
# 53013980                                             0.03
# 53001893                                             0.03
#
#              NU_PROP_PSS_MULHERES_SC_SCHL  NU_PROP_PSS_MULHERES_RSP_SC_SCHL  \
# CO_ENTIDADE
# 53001206                             0.55                              0.16
# 53011988                             0.51                              0.13
# 53068181                             0.51                              0.12
# 53013980                             0.55                              0.17
# 53001893                             0.55                              0.17
#
#              NU_PROP_PSS_ABXO_12ANOS_SC_SCHL  \
# CO_ENTIDADE
# 53001206                                0.12
# 53011988                                0.23
# 53068181                                0.22
# 53013980                                0.12
# 53001893                                0.12
#
#              NU_PROP_PSS_ACIMA_65ANOS_SC_SCHL  \
# CO_ENTIDADE
# 53001206                                 0.13
# 53011988                                 0.05
# 53068181                                 0.03
# 53013980                                 0.12
# 53001893                                 0.12
#
#              NU_PROP_PSS_ACIMA_90ANOS_SC_SCHL  CO_CLUSTER_SCHL  \
# CO_ENTIDADE
# 53001206                                 0.00                0
# 53011988                                 0.00               31
# 53068181                                 0.00               31
# 53013980                                 0.00                0
# 53001893                                 0.00                0
#
#              NU_LATITUDE_SCHL  NU_LONGITUDE_SCHL
# CO_ENTIDADE
# 53001206               -15.83             -47.91
# 53011988               -15.66             -48.19
# 53068181               -16.03             -48.03
# 53013980               -15.80             -47.91
# 53001893               -15.81             -47.91
#
# [5 rows x 59 columns]
# <table>
# <tbody>
# <tr><td>IN_ESGOTO_REDE_PUBLICA_SCHL                  </td><td>float16 </td></tr>
# <tr><td>IN_ESGOTO_FOSSA_SCHL                         </td><td>float16 </td></tr>
# <tr><td>IN_LABORATORIO_INFORMATICA_SCHL              </td><td>float16 </td></tr>
# <tr><td>IN_LABORATORIO_CIENCIAS_SCHL                 </td><td>float16 </td></tr>
# <tr><td>IN_SALA_ATENDIMENTO_ESPECIAL_SCHL            </td><td>float16 </td></tr>
# <tr><td>IN_QUADRA_ESPORTES_COBERTA_SCHL              </td><td>float16 </td></tr>
# <tr><td>IN_QUADRA_ESPORTES_DESCOBERTA_SCHL           </td><td>float16 </td></tr>
# <tr><td>IN_QUADRA_ESPORTES_SCHL                      </td><td>float16 </td></tr>
# <tr><td>IN_BIBLIOTECA_SCHL                           </td><td>float16 </td></tr>
# <tr><td>IN_SALA_LEITURA_SCHL                         </td><td>float16 </td></tr>
# <tr><td>IN_BIBLIOTECA_SALA_LEITURA_SCHL              </td><td>float16 </td></tr>
# <tr><td>IN_PARQUE_INFANTIL_SCHL                      </td><td>float16 </td></tr>
# <tr><td>IN_BANHEIRO_EI_SCHL                          </td><td>float16 </td></tr>
# <tr><td>IN_BANHEIRO_PNE_SCHL                         </td><td>float16 </td></tr>
# <tr><td>IN_DEPENDENCIAS_PNE_SCHL                     </td><td>float16 </td></tr>
# <tr><td>IN_BANHEIRO_CHUVEIRO_SCHL                    </td><td>float16 </td></tr>
# <tr><td>IN_REFEITORIO_SCHL                           </td><td>float16 </td></tr>
# <tr><td>IN_DESPENSA_SCHL                             </td><td>float16 </td></tr>
# <tr><td>IN_ALMOXARIFADO_SCHL                         </td><td>float16 </td></tr>
# <tr><td>IN_AUDITORIO_SCHL                            </td><td>float16 </td></tr>
# <tr><td>IN_PATIO_COBERTO_SCHL                        </td><td>float16 </td></tr>
# <tr><td>IN_PATIO_DESCOBERTO_SCHL                     </td><td>float16 </td></tr>
# <tr><td>IN_AREA_VERDE_SCHL                           </td><td>float16 </td></tr>
# <tr><td>NU_SALAS_EXISTENTES_SCHL                     </td><td>float16 </td></tr>
# <tr><td>IN_EQUIP_VIDEOCASSETE_SCHL                   </td><td>float16 </td></tr>
# <tr><td>IN_EQUIP_PARABOLICA_SCHL                     </td><td>float16 </td></tr>
# <tr><td>IN_EQUIP_RETROPROJETOR_SCHL                  </td><td>float16 </td></tr>
# <tr><td>IN_EQUIP_IMPRESSORA_MULT_SCHL                </td><td>float16 </td></tr>
# <tr><td>IN_EQUIP_FAX_SCHL                            </td><td>float16 </td></tr>
# <tr><td>IN_EQUIP_FOTO_SCHL                           </td><td>float16 </td></tr>
# <tr><td>NU_COMPUTADOR_SCHL                           </td><td>float16 </td></tr>
# <tr><td>NU_COMP_ADMINISTRATIVO_SCHL                  </td><td>float16 </td></tr>
# <tr><td>NU_COMP_ALUNO_SCHL                           </td><td>float16 </td></tr>
# <tr><td>NU_FUNCIONARIOS_SCHL                         </td><td>float16 </td></tr>
# <tr><td>IN_AEE_SCHL                                  </td><td>float16 </td></tr>
# <tr><td>IN_ATIVIDADE_COMPLEMENTAR_SCHL               </td><td>float16 </td></tr>
# <tr><td>IN_FINAL_SEMANA_SCHL                         </td><td>float16 </td></tr>
# <tr><td>NU_PROP_FUNS_SALAS_UTZD_SCHL                 </td><td>float16 </td></tr>
# <tr><td>NU_PROP_CPU_SALAS_UTZD_SCHL                  </td><td>float16 </td></tr>
# <tr><td>NU_QTD_SETORES_CENSITARIOS_SC_SCHL           </td><td>int16   </td></tr>
# <tr><td>NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SC_SCHL      </td><td>float16 </td></tr>
# <tr><td>NU_MEDIANA_RENDA_MEDIA_SC_SCHL               </td><td>float16 </td></tr>
# <tr><td>NU_MEDIANA_QTD_DOMICILIOS_SC_SCHL            </td><td>float16 </td></tr>
# <tr><td>NU_MEDIANA_QTD_PESSOAS_SC_SCHL               </td><td>float16 </td></tr>
# <tr><td>NU_SOMA_QTD_DOMICILIOS_SC_SCHL               </td><td>int16   </td></tr>
# <tr><td>NU_SOMA_QTD_PESSOAS_SC_SCHL                  </td><td>int16   </td></tr>
# <tr><td>NU_PROP_DOM_ALUGADOS_SC_SCHL                 </td><td>float16 </td></tr>
# <tr><td>NU_PROP_DOM_CEDIDOS_SC_SCHL                  </td><td>float16 </td></tr>
# <tr><td>NU_PROP_DOM_EM_AQUISICAO_SC_SCHL             </td><td>float16 </td></tr>
# <tr><td>NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SC_SCHL</td><td>float16 </td></tr>
# <tr><td>NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SC_SCHL </td><td>float16 </td></tr>
# <tr><td>NU_PROP_PSS_MULHERES_SC_SCHL                 </td><td>float16 </td></tr>
# <tr><td>NU_PROP_PSS_MULHERES_RSP_SC_SCHL             </td><td>float16 </td></tr>
# <tr><td>NU_PROP_PSS_ABXO_12ANOS_SC_SCHL              </td><td>float16 </td></tr>
# <tr><td>NU_PROP_PSS_ACIMA_65ANOS_SC_SCHL             </td><td>float16 </td></tr>
# <tr><td>NU_PROP_PSS_ACIMA_90ANOS_SC_SCHL             </td><td>float16 </td></tr>
# <tr><td>CO_CLUSTER_SCHL                              </td><td>category</td></tr>
# <tr><td>NU_LATITUDE_SCHL                             </td><td>float16 </td></tr>
# <tr><td>NU_LONGITUDE_SCHL                            </td><td>float16 </td></tr>
# </tbody>
# </table>

# %%
Visualizacao.explora_df(schl.drop(['NU_LATITUDE_SCHL','NU_LONGITUDE_SCHL'],axis=1))
# Out:
# <h2>1. IN_ESGOTO_REDE_PUBLICA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.126708984375'
#       qtd   pc
# 1.00  424 0.85
# 0.00   74 0.15
# <hr/>
# <h2>2. IN_ESGOTO_FOSSA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.126708984375'
#       qtd   pc
# 0.00  424 0.85
# 1.00   74 0.15
# <hr/>
# <h2>3. IN_LABORATORIO_INFORMATICA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.149658203125'
#       qtd   pc
# 1.00  407 0.82
# 0.00   91 0.18
# <hr/>
# <h2>4. IN_LABORATORIO_CIENCIAS_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.14697265625'
#       qtd   pc
# 0.00  409 0.82
# 1.00   89 0.18
# <hr/>
# <h2>5. IN_SALA_ATENDIMENTO_ESPECIAL_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.1746826171875'
#       qtd   pc
# 1.00  386 0.78
# 0.00  112 0.22
# <hr/>
# <h2>6. IN_QUADRA_ESPORTES_COBERTA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.1832275390625'
#       qtd   pc
# 0.00  378 0.76
# 1.00  120 0.24
# <hr/>
# <h2>7. IN_QUADRA_ESPORTES_DESCOBERTA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2489013671875'
#       qtd   pc
# 0.00  269 0.54
# 1.00  229 0.46
# <hr/>
# <h2>8. IN_QUADRA_ESPORTES_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.23193359375'
#       qtd   pc
# 1.00  317 0.64
# 0.00  181 0.36
# <hr/>
# <h2>9. IN_BIBLIOTECA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2132568359375'
#       qtd   pc
# 0.00  345 0.69
# 1.00  153 0.31
# <hr/>
# <h2>10. IN_SALA_LEITURA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.1951904296875'
#       qtd   pc
# 1.00  366 0.73
# 0.00  132 0.27
# <hr/>
# <h2>11. IN_BIBLIOTECA_SALA_LEITURA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.10772705078125'
#       qtd   pc
# 1.00  437 0.88
# 0.00   61 0.12
# <hr/>
# <h2>12. IN_PARQUE_INFANTIL_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.250244140625'
#       qtd   pc
# 1.00  257 0.52
# 0.00  241 0.48
# <hr/>
# <h2>13. IN_BANHEIRO_EI_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.228271484375'
#       qtd   pc
# 0.00  323 0.65
# 1.00  175 0.35
# <hr/>
# <h2>14. IN_BANHEIRO_PNE_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.1712646484375'
#       qtd   pc
# 1.00  389 0.78
# 0.00  109 0.22
# <hr/>
# <h2>15. IN_DEPENDENCIAS_PNE_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2279052734375'
#       qtd   pc
# 1.00  324 0.65
# 0.00  174 0.35
# <hr/>
# <h2>16. IN_BANHEIRO_CHUVEIRO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.25048828125'
#       qtd   pc
# 1.00  252 0.51
# 0.00  246 0.49
# <hr/>
# <h2>17. IN_REFEITORIO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.164306640625'
#       qtd   pc
# 0.00  395 0.79
# 1.00  103 0.21
# <hr/>
# <h2>18. IN_DESPENSA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.221923828125'
#       qtd   pc
# 1.00  333 0.67
# 0.00  165 0.33
# <hr/>
# <h2>19. IN_ALMOXARIFADO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.19970703125'
#       qtd   pc
# 0.00  361 0.72
# 1.00  137 0.28
# <hr/>
# <h2>20. IN_AUDITORIO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.10321044921875'
#       qtd   pc
# 0.00  440 0.88
# 1.00   58 0.12
# <hr/>
# <h2>21. IN_PATIO_COBERTO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.1961669921875'
#       qtd   pc
# 1.00  365 0.73
# 0.00  133 0.27
# <hr/>
# <h2>22. IN_PATIO_DESCOBERTO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.24169921875'
#       qtd   pc
# 0.00  296 0.59
# 1.00  202 0.41
# <hr/>
# <h2>23. IN_AREA_VERDE_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2489013671875'
#       qtd   pc
# 0.00  269 0.54
# 1.00  229 0.46
# <hr/>
# <h2>24. NU_SALAS_EXISTENTES_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 61.5'
# count   498.00
# mean     14.82
# std       7.84
# min       2.00
# 25%       9.00
# 50%      15.00
# 75%      19.75
# max      84.00
# Name: NU_SALAS_EXISTENTES_SCHL, dtype: float64
# <hr/>
# <h2>25. IN_EQUIP_VIDEOCASSETE_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.244384765625'
#       qtd   pc
# 1.00  288 0.58
# 0.00  210 0.42
# <hr/>
# <h2>26. IN_EQUIP_PARABOLICA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2470703125'
#       qtd   pc
# 1.00  278 0.56
# 0.00  220 0.44
# <hr/>
# <h2>27. IN_EQUIP_RETROPROJETOR_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.1595458984375'
#       qtd   pc
# 1.00  399 0.80
# 0.00   99 0.20
# <hr/>
# <h2>28. IN_EQUIP_IMPRESSORA_MULT_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.221435546875'
#       qtd   pc
# 0.00  334 0.67
# 1.00  164 0.33
# <hr/>
# <h2>29. IN_EQUIP_FAX_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2423095703125'
#       qtd   pc
# 0.00  294 0.59
# 1.00  204 0.41
# <hr/>
# <h2>30. IN_EQUIP_FOTO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.21630859375'
#       qtd   pc
# 1.00  341 0.68
# 0.00  157 0.32
# <hr/>
# <h2>31. NU_COMPUTADOR_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: inf'
# count   498.00
# mean     26.42
# std        inf
# min       0.00
# 25%      14.00
# 50%      22.00
# 75%      30.75
# max     639.00
# Name: NU_COMPUTADOR_SCHL, dtype: float64
# <hr/>
# <h2>32. NU_COMP_ADMINISTRATIVO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 27.734375'
# count   498.00
# mean      4.76
# std       5.27
# min       0.00
# 25%       2.00
# 50%       4.00
# 75%       6.00
# max      53.00
# Name: NU_COMP_ADMINISTRATIVO_SCHL, dtype: float64
# <hr/>
# <h2>33. NU_COMP_ALUNO_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 155.5'
# count   498.00
# mean     14.32
# std      12.47
# min       0.00
# 25%       1.00
# 50%      14.00
# 75%      20.00
# max      80.00
# Name: NU_COMP_ALUNO_SCHL, dtype: float64
# <hr/>
# <h2>34. NU_FUNCIONARIOS_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: inf'
# count   498.00
# mean     76.50
# std        inf
# min      10.00
# 25%      48.25
# 50%      70.00
# 75%      96.00
# max     392.00
# Name: NU_FUNCIONARIOS_SCHL, dtype: float64
# <hr/>
# <h2>35. IN_AEE_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2369384765625'
#       qtd   pc
# 1.00  307 0.62
# 0.00  191 0.38
# <hr/>
# <h2>36. IN_ATIVIDADE_COMPLEMENTAR_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.2313232421875'
#       qtd   pc
# 0.00  318 0.64
# 1.00  180 0.36
# <hr/>
# <h2>37. IN_FINAL_SEMANA_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.15576171875'
#       qtd   pc
# 0.00  402 0.81
# 1.00   96 0.19
# <hr/>
# <h2>38. NU_PROP_FUNS_SALAS_UTZD_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 2.529296875'
# count   498.00
# mean      5.64
# std       1.59
# min       2.00
# 25%       4.64
# 50%       5.40
# 75%       6.36
# max      17.00
# Name: NU_PROP_FUNS_SALAS_UTZD_SCHL, dtype: float64
# <hr/>
# <h2>39. NU_PROP_CPU_SALAS_UTZD_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 8.5546875'
# count   498.00
# mean      2.03
# std       2.93
# min       0.00
# 25%       1.11
# 50%       1.75
# 75%       2.45
# max      60.75
# Name: NU_PROP_CPU_SALAS_UTZD_SCHL, dtype: float64
# <hr/>
# <h2>40. NU_QTD_SETORES_CENSITARIOS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 10163.814873174792'
# count   498.00
# mean    158.67
# std     100.82
# min       1.00
# 25%      86.75
# 50%     154.50
# 75%     202.00
# max     432.00
# Name: NU_QTD_SETORES_CENSITARIOS_SC_SCHL, dtype: float64
# <hr/>
# <h2>41. NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.0870361328125'
# count   498.00
# mean      1.57
# std       0.29
# min       1.04
# 25%       1.43
# 50%       1.52
# 75%       1.66
# max       4.85
# Name: NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SC_SCHL, dtype: float64
# <hr/>
# <h2>42. NU_MEDIANA_RENDA_MEDIA_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: inf'
# count     498.00
# mean         inf
# std          inf
# min      1101.00
# 25%      1915.00
# 50%      2480.00
# 75%      5244.00
# max     14048.00
# Name: NU_MEDIANA_RENDA_MEDIA_SC_SCHL, dtype: float64
# <hr/>
# <h2>43. NU_MEDIANA_QTD_DOMICILIOS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 656.0'
# count   498.00
# mean       inf
# std      25.61
# min      34.00
# 25%     169.00
# 50%     181.00
# 75%     189.00
# max     215.50
# Name: NU_MEDIANA_QTD_DOMICILIOS_SC_SCHL, dtype: float64
# <hr/>
# <h2>44. NU_MEDIANA_QTD_PESSOAS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: inf'
# count   498.00
# mean       inf
# std        inf
# min     105.00
# 25%     533.50
# 50%     609.50
# 75%     668.00
# max     769.00
# Name: NU_MEDIANA_QTD_PESSOAS_SC_SCHL, dtype: float64
# <hr/>
# <h2>45. NU_SOMA_QTD_DOMICILIOS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 432951410.8624599'
# count      498.00
# mean      4302.05
# std      20807.48
# min     -32721.00
# 25%     -12024.00
# 50%       9870.00
# 75%      21133.00
# max      32697.00
# Name: NU_SOMA_QTD_DOMICILIOS_SC_SCHL, dtype: float64
# <hr/>
# <h2>46. NU_SOMA_QTD_PESSOAS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 308962429.78995264'
# count      498.00
# mean      1614.03
# std      17577.33
# min     -31623.00
# 25%     -11291.50
# 50%       2086.00
# 75%      15459.00
# max      32356.00
# Name: NU_SOMA_QTD_PESSOAS_SC_SCHL, dtype: float64
# <hr/>
# <h2>47. NU_PROP_DOM_ALUGADOS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.0078277587890625'
# count   498.00
# mean      0.30
# std       0.09
# min       0.00
# 25%       0.27
# 50%       0.32
# 75%       0.36
# max       0.45
# Name: NU_PROP_DOM_ALUGADOS_SC_SCHL, dtype: float64
# <hr/>
# <h2>48. NU_PROP_DOM_CEDIDOS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.00858306884765625'
# count   498.00
# mean      0.12
# std       0.09
# min       0.04
# 25%       0.08
# 50%       0.10
# 75%       0.11
# max       1.00
# Name: NU_PROP_DOM_CEDIDOS_SC_SCHL, dtype: float64
# <hr/>
# <h2>49. NU_PROP_DOM_EM_AQUISICAO_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.0009679794311523438'
# count   498.00
# mean      0.04
# std       0.03
# min       0.00
# 25%       0.01
# 50%       0.04
# 75%       0.06
# max       0.17
# Name: NU_PROP_DOM_EM_AQUISICAO_SC_SCHL, dtype: float64
# <hr/>
# <h2>50. NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.0552978515625'
# count   498.00
# mean      0.19
# std       0.24
# min       0.00
# 25%       0.02
# 50%       0.06
# 75%       0.24
# max       0.71
# Name: NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SC_SCHL, dtype: float64
# <hr/>
# <h2>51. NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.048858642578125'
# count   498.00
# mean      0.39
# std       0.22
# min       0.02
# 25%       0.20
# 50%       0.41
# 75%       0.55
# max       0.82
# Name: NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SC_SCHL, dtype: float64
# <hr/>
# <h2>52. NU_PROP_PSS_MULHERES_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.00047135353088378906'
# count   498.00
# mean      0.52
# std       0.02
# min       0.40
# 25%       0.51
# 50%       0.52
# 75%       0.53
# max       0.55
# Name: NU_PROP_PSS_MULHERES_SC_SCHL, dtype: float64
# <hr/>
# <h2>53. NU_PROP_PSS_MULHERES_RSP_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.0005521774291992188'
# count   498.00
# mean      0.13
# std       0.02
# min       0.02
# 25%       0.12
# 50%       0.13
# 75%       0.14
# max       0.18
# Name: NU_PROP_PSS_MULHERES_RSP_SC_SCHL, dtype: float64
# <hr/>
# <h2>54. NU_PROP_PSS_ABXO_12ANOS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.0019092559814453125'
# count   498.00
# mean      0.19
# std       0.04
# min       0.11
# 25%       0.16
# 50%       0.20
# 75%       0.22
# max       0.30
# Name: NU_PROP_PSS_ABXO_12ANOS_SC_SCHL, dtype: float64
# <hr/>
# <h2>55. NU_PROP_PSS_ACIMA_65ANOS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 0.0007843971252441406'
# count   498.00
# mean      0.06
# std       0.03
# min       0.01
# 25%       0.03
# 50%       0.05
# 75%       0.07
# max       0.15
# Name: NU_PROP_PSS_ACIMA_65ANOS_SC_SCHL, dtype: float64
# <hr/>
# <h2>56. NU_PROP_PSS_ACIMA_90ANOS_SC_SCHL</h2>
# '0.0% de registros nulos'
# 'Variância: 8.940696716308594e-07'
# count   498.00
# mean      0.00
# std       0.00
# min       0.00
# 25%       0.00
# 50%       0.00
# 75%       0.00
# max       0.01
# Name: NU_PROP_PSS_ACIMA_90ANOS_SC_SCHL, dtype: float64
# <hr/>
# <h2>57. CO_CLUSTER_SCHL</h2>
# '0.0% de registros nulos'
# Não foi possível calcular a variância.
#     qtd   pc
# 31  141 0.28
# 30  102 0.20
# 1    93 0.19
# 0    89 0.18
# 2    73 0.15
# <hr/>

# %% [markdown]
# #### Algumas observações:
# - 133 escolas não possuíam pátio coberto, como será que os alunos comiam em dias chuvosos?
# - A maior escola tinha 84 salas de aula, a menor só tinha duas.
# - Mesmo sendo um equipamento ultrapassado 52% das escolas possuíam vídeo cassete e, por outro lado, somente 33% (164) possuíam impressora multifuncional.
# - 25% das escolas possuem um ou menos computador para os alunos.
# - O número de funcionários segue uma distribuição assimétrica POSITIVA OU NEGATIVA?

# %% [markdown]
# ### 2.2 Análise geográfica das saídas

# %% [markdown]
# Aonde ficam as escolas com as maiores taxas de saída?

# %% [markdown]
# #### 2.2.1 Montar a variável _turn over_ que mede a proporção de professores que saíram de uma escola

# %%
#criacao da variavel TURN OVER
a = mv.reset_index().groupby('CO_ENTIDADE').IN_SAIU_ESCOLA.sum()
b = mv.reset_index().groupby('CO_ENTIDADE').CO_PESSOA_FISICA.count()
schl['TURN_OVER'] = a/b

# %% [markdown]
# #### 2.2.2 Análise do _turn over_

# %%
#resumo da variavel
display(schl.TURN_OVER.describe())
schl.TURN_OVER.hist();
# Out:
# count   498.00
# mean      0.24
# std       0.20
# min       0.00
# 25%       0.09
# 50%       0.20
# 75%       0.33
# max       1.00
# Name: TURN_OVER, dtype: float64

# %%
#Plotagem das faixas do quantis do turnover.
#Divide o TURN OVER em 5 faixas
schl['FX_TURN_OVER'] = pd.qcut(schl.TURN_OVER, 5, labels=False)

#plota o mapa
lclz_praca_3_poderes = [-15.7994, -47.8613]
mapa = folium.Map(location=lclz_praca_3_poderes, zoom_start=10)
cores = ['blue', 'green','orange', 'purple', 'red']
for ltg,lng,fx in schl[['NU_LATITUDE_SCHL','NU_LONGITUDE_SCHL','FX_TURN_OVER']].values:
    folium.Marker([ltg,lng],icon=folium.Icon(color=cores[int(fx)-1],icon='map-marker-alt')).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Algumas observações:
#
# - Mesmo havendo alguns pontos vermelhos nas extremidades, pareceu-me que os pontos estão bem distribuídos pelo mapa.
# - Logo a localização da escola não é, por si só, motivo de saída.

# %% [markdown]
# ### 2.3 Gráficos bivariados

# %% [markdown]
# #### 2.3.1 Será que os turn overs estão relacionados com o tamanho da escola?

# %%
#plota a correlação entre a quantidade de funcionários da escola, quantidade de salas existentes e o turnover
Visualizacao.plota_matriz_heatmap( schl[['NU_FUNCIONARIOS_SCHL','NU_SALAS_EXISTENTES_SCHL','TURN_OVER']].corr())
# Out:
# <style  type="text/css" >
#     #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79 th {
#           font-size: 7pt;
#     }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79 td {
#           padding: 0em 0em;
#     }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79 th:hover {
#           font-size: 12pt;
#     }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row0_col1 {
#             background-color:  #8babd4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row0_col2 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row1_col0 {
#             background-color:  #8babd4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row1_col2 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row2_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row2_col1 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row2_col2 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }</style>
# <table id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79" ><caption>Hover to magify</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >NU_FUNCIONARIOS_SCHL</th>
#         <th class="col_heading level0 col1" >NU_SALAS_EXISTENTES_SCHL</th>
#         <th class="col_heading level0 col2" >TURN_OVER</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79level0_row0" class="row_heading level0 row0" >NU_FUNCIONARIOS_SCHL</th>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row0_col0" class="data row0 col0" >1</td>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row0_col1" class="data row0 col1" >0.8</td>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row0_col2" class="data row0 col2" >0.0086</td>
#     </tr>    <tr>
#         <th id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79level0_row1" class="row_heading level0 row1" >NU_SALAS_EXISTENTES_SCHL</th>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row1_col0" class="data row1 col0" >0.8</td>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row1_col1" class="data row1 col1" >1</td>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row1_col2" class="data row1 col2" >0.0069</td>
#     </tr>    <tr>
#         <th id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79level0_row2" class="row_heading level0 row2" >TURN_OVER</th>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row2_col0" class="data row2 col0" >0.0086</td>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row2_col1" class="data row2 col1" >0.0069</td>
#         <td id="T_21c2bb16_bda7_11e8_b1b3_58fb84744e79row2_col2" class="data row2 col2" >1</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# A correlação parece mostrar que não.
#
# #### 2.3.2 Será que os dados do entorno da escola estão conectados com o turn over?

# %%
#seleciona as colunas de setores sensitários, dropa a linha do turnover e plota o gráfico de barras
schl[
        [col for col in schl.columns 
         if col.endswith('SC_SCHL')
         or col == 'TURN_OVER']].corr()[['TURN_OVER']].drop('TURN_OVER')\
            .plot.bar(
                        title='Correlação entre a saída de professores e a vizinhança', 
                        figsize=(12,7));

# %% [markdown]
# A baixa amplitude das correlações indica que o entorno da escola parece não estar correlacionado com o turnover.

# %% [markdown]
# #### 2.3.3 Qual a faixa etária dos professores que saem?

# %%
#vamos agregar os dados por idade e ver a proporção dos que saíram em relação ao total da referida idade.
#agrupa por idade e saída
def monta_dados_grafico_idade(m):
    a = m.reset_index()\
        .groupby(['NU_IDADE_REFERENCIA_PROF','IN_SAIU_ESCOLA'])[['CO_PESSOA_FISICA']]\
        .count()\
        .reset_index()
    a.columns = ['Idade do professor','Indicador de saída','Qtd']
    #total de professores com a referida idade.
    b = m.groupby('NU_IDADE_REFERENCIA_PROF')['IN_SAIU_ESCOLA'].count()
    #cria a coluna de proporção
    a['Percentual de saidas'] = 0
    #percorre as idades e calcula as proporções
    for q in b.reset_index().values:
        c = a.loc[a['Idade do professor'] == q[0]]
        a.loc[a['Idade do professor'] == q[0],'Percentual de saidas'] = c['Qtd']/q[1] * 100
    return a
#plotagem
#define um tamanho de gráfico agradável para visualização
plt.figure(figsize=(12,8))
plt.title('Proporção de saídas x Idade do professor')
sns.set_palette('Blues_d')
sns.pointplot(data=monta_dados_grafico_idade(mv),
              x='Idade do professor',
              y='Percentual de saidas',
              hue='Indicador de saída',);
mv[['NU_IDADE_REFERENCIA_PROF','IN_SAIU_ESCOLA']].corr()
# Out:
#                           NU_IDADE_REFERENCIA_PROF  IN_SAIU_ESCOLA
# NU_IDADE_REFERENCIA_PROF                      1.00           -0.18
# IN_SAIU_ESCOLA                               -0.18            1.00

# %% [markdown]
# #### Temos um indicativo:
# Os professores mais novos parecem que saem mais.
#
# E isso faz bastante sentido, pois a tendência é a pessoa estabilizar em algum lugar.

# %% [markdown]
# #### 2.3.4 Onde os professores mais velhos lecionam?

# %%
#divide em quartis
mv['FX_IDADE'] = pd.qcut(mv.NU_IDADE_REFERENCIA_PROF,4,labels=['1','2','3','4'])
display(mv.head(1000).FX_IDADE.value_counts())

#plota o mapa
lclz_praca_3_poderes = [-15.7994, -47.8613]
mapa = folium.Map(location=lclz_praca_3_poderes, zoom_start=10)
cores = ['blue', 'green', 'purple', 'red']
for ltg,lng,fx in mv[['NU_LATITUDE_SCHL','NU_LONGITUDE_SCHL','FX_IDADE']].head(1000).values:
    folium.Marker([ltg,lng],icon=folium.Icon(color=cores[int(fx)-1],icon='map-marker-alt')).add_to(mapa)
mapa
# Out:
# 4    275
# 3    249
# 1    249
# 2    227
# Name: FX_IDADE, dtype: int64
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 2.3.5 As escolas com melhor infraestrutura estão em lugares com maior renda?
#
# Vamos investigar se o governo do Distrito Federal equipa melhor as escolas com uma vizinhança mais abastada.
#
# Variáveis que utilizei:
#
# Para infraestrutura utilizei as features que entendi serem mais representativas de uma escola bem estruturada.
#
# Para os setores sensitários utilizei as features mais representativas de renda. O percentual de pessoas acima de 65 anos tem bastante correlação com a renda (ricos vivem mais, além disso idosos geralmente possuem uma renda própria).

# %%
#features de infraestrutura da escola
features_infra = [
    'IN_LABORATORIO_INFORMATICA_SCHL',
    'IN_LABORATORIO_CIENCIAS_SCHL',
    'IN_QUADRA_ESPORTES_COBERTA_SCHL',
    'IN_BIBLIOTECA_SALA_LEITURA_SCHL',
    'IN_PARQUE_INFANTIL_SCHL',
    'IN_BANHEIRO_PNE_SCHL',
    'IN_AUDITORIO_SCHL',
    'IN_EQUIP_IMPRESSORA_MULT_SCHL',
    'NU_COMPUTADOR_SCHL',
    'NU_COMP_ALUNO_SCHL'
]

#features de setores censitários
features_sc = [
    'NU_MEDIANA_RENDA_MEDIA_SC_SCHL',
    'NU_QTD_SETORES_CENSITARIOS_SC_SCHL',
    'NU_SOMA_QTD_PESSOAS_SC_SCHL',
    'NU_PROP_PSS_ACIMA_65ANOS_SC_SCHL'
    
]
b = schl[features_infra + features_sc].copy()
#Soma os indicadores de infraestrutura
b['Qtd itens infra'] = np.sum(b[[col for col in features_infra if col.startswith('IN_')]],axis=1)
#Deleta as colunas de indicadores
b.drop([col for col in features_infra if col.startswith('IN_')],axis=1,inplace=True)
#Renomeia as colunas para deixar os gráficos mais "simpáticos"
b.rename(columns={'NU_COMPUTADOR_SCHL': 'Qtd Computadores',
                   'NU_COMP_ALUNO_SCHL': 'Qtd cpu alunos',
                   'NU_MEDIANA_RENDA_MEDIA_SC_SCHL' : 'Renda',
                   'NU_QTD_SETORES_CENSITARIOS_SC_SCHL' : 'Qtd Setores',
                   'NU_PROP_PSS_ACIMA_65ANOS_SC_SCHL' : '% pessoas 65 +',
                   'NU_SOMA_QTD_PESSOAS_SC_SCHL' : 'População' },inplace=True)

# %%
sns.pairplot(b);

# %% [markdown]
# Muito bem GDF, há indícios de não existir diferença na estrutura de escolas públicas devido a vizinhança!

# %% [markdown]
# Vamos plotar a matriz de correlação para aumentarmos a certeza do que estamos falando.

# %%
Visualizacao.plota_matriz_heatmap(b.corr())
# Out:
# <style  type="text/css" >
#     #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79 th {
#           font-size: 7pt;
#     }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79 td {
#           padding: 0em 0em;
#     }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79 th:hover {
#           font-size: 12pt;
#     }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row0_col1 {
#             background-color:  #eb9ead;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row0_col2 {
#             background-color:  #d94563;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row0_col3 {
#             background-color:  #e27389;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row0_col4 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row0_col5 {
#             background-color:  #d83e5d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row0_col6 {
#             background-color:  #e47a90;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row1_col0 {
#             background-color:  #ea96a7;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row1_col2 {
#             background-color:  #d83e5d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row1_col3 {
#             background-color:  #e47a90;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row1_col4 {
#             background-color:  #d83e5d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row1_col5 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row1_col6 {
#             background-color:  #f5cfd7;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row2_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row2_col1 {
#             background-color:  #d8405e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row2_col2 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row2_col3 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row2_col4 {
#             background-color:  #f0b4c0;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row2_col5 {
#             background-color:  #81a4d1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row2_col6 {
#             background-color:  #da4865;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row3_col0 {
#             background-color:  #e16981;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row3_col1 {
#             background-color:  #e47c91;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row3_col2 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row3_col3 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row3_col4 {
#             background-color:  #db4e6a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row3_col5 {
#             background-color:  #e06880;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row3_col6 {
#             background-color:  #df617a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row4_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row4_col1 {
#             background-color:  #da4966;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row4_col2 {
#             background-color:  #f1bcc7;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row4_col3 {
#             background-color:  #dd5872;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row4_col4 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row4_col5 {
#             background-color:  #ec9faf;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row4_col6 {
#             background-color:  #d94563;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row5_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row5_col1 {
#             background-color:  #d94261;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row5_col2 {
#             background-color:  #7fa3d0;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row5_col3 {
#             background-color:  #e26f86;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row5_col4 {
#             background-color:  #eb9dac;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row5_col5 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row5_col6 {
#             background-color:  #d8415f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row6_col0 {
#             background-color:  #e27288;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row6_col1 {
#             background-color:  #f6d1d8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row6_col2 {
#             background-color:  #da4966;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row6_col3 {
#             background-color:  #df627b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2a6081f4_bda7_11e8_b1b3_58fb84744e79row6_col4 {

# %% [markdown]
# Aparentemente os recursos governamentais da área da educação estão bem distribuídos no DF, se fôssemos fazer uma crítica seria somente à pequena correlação negativa entre a quantidade de computadores para alunos e a população na vizinhança, entretanto isso pode ter a ver com alguns outliers que podem ser vistos no pairplot acima.

# %% [markdown]
# ### 3. Gráficos finais
#
# Os gráficos que mais me chamaram a atenção para responder a questão inicial foram:

# %% [markdown]
# #### 3.1 Proporção de saídas x Idade do professor
# Aqui adicionei o histograma (feito com um gráfico e barras) para visualizar o total de professores com a respectiva idade.

# %%
#Proporção de saídas x Idade do professor
#define um tamanho de gráfico agradável para visualização
fig, ax = plt.subplots(figsize = (12,8))

#titulo do grafico
plt.title('Proporção de saídas x Idade do professor')
#desenha a linha vertical
ax.axvline(x=4,linestyle=':',color='b')
#seta o eixo secundario
ax2 = ax.twinx()
#dados do grafico de barras (o histograma nao ficou legal).
d  = pd.DataFrame(prof.NU_IDADE_REFERENCIA_PROF.value_counts().sort_index())
d.reset_index(inplace=True)
d.columns = ['Idade do professor', 'Qtd de professores']
#plota o grafico de barras
sns.barplot(x='Idade do professor',y='Qtd de professores',data=d,ax=ax2,color='k',facecolor=(1, 1, 1, 0),edgecolor=".2")
#plotagem
sns.pointplot(data=monta_dados_grafico_idade(mv),
              x='Idade do professor',
              y='Percentual de saidas',
              hue='Indicador de saída',ax=ax);
plt.show()

# %% [markdown]
# #### 3.2 Faixa de idade do professor x Localização da escola

# %%
#Idade do professor x Localização da escola
lclz_praca_3_poderes = [-15.7994, -47.8613]
mapa = folium.Map(location=lclz_praca_3_poderes, zoom_start=10)
#Primeiro quartil será o azul, o segundo verde o terceiro rosa e o último o vermelho.
cores = ['blue', 'green', 'purple', 'red']
for ltg,lng,fx in mv[['NU_LATITUDE_SCHL','NU_LONGITUDE_SCHL','FX_IDADE']].head(1000).values:
    folium.Marker([ltg,lng],icon=folium.Icon(color=cores[int(fx)-1],icon='map-marker-alt')).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Observação interessante:
# Esses dois gráficos em conjunto mostram algo bastante interessante: os professores de mais idade (_pins_ vermelhos) dão aula em escolas mais centrais, ou provavelmente perto de onde residem (região da Samambaia), enquanto os mais novos (mais fortemente os _pins_ azuis  e, em menor medida, os verdes) estão distribuídos em regiões mais afastadas.

# %% [markdown]
# #### 3.3 Modelagem
#
# Será que somente a idade é influenciadora da transferência?
#
# Vamos rodar dois algoritmos de Machine Learning que possuem o _feature importance_ para verificar quais outras variáveis impactam na hora de pedir transferência.

# %%
#selecao de features
df_mod = mv.drop(['NU_LATITUDE_SCHL','NU_LONGITUDE_SCHL'],axis=1).copy()
#ajuste nos tipos das colunas
for col in df_mod.columns:
    if col.startswith('IN_'):
        df_mod[col] = pd.Categorical(df_mod[col])

#modelos de árvores são pouco propensos a viés por não normalização, portanto pularemos 
#essa parte.

# %%
#verifica a quantidade de nulos
df_mod[df_mod.isnull().any(axis=1)].shape
# Out:
# (4, 82)

# %%
#somente 4 linhas, então podemos apagá-las sem dor na consciência.
display(df_mod.shape)
df_mod.dropna(inplace=True)
df_mod.shape
# Out:
# (8187, 82)
# (8183, 82)

# %% [markdown]
# Não irei me aprofundar nos modelos pois está fora do escopo desse trabalho (e poderia ser tema, de no mínimo, uma dissertação), mas veremos que a modelagem simples já ajudará um pouco.

# %%
import modelagem
#modela com Random Forest
ft_rf,_ = modelagem.processa_tudo(df_mod,tg='IN_SAIU_ESCOLA',vai_escalar=False);
# Out:
# /home/itsbarreto/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Base de TREINO
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      4654
#           1       0.99      0.92      0.95      1483
#
# avg / total       0.98      0.98      0.98      6137
#
# Base de TESTE
#              precision    recall  f1-score   support
#
#           0       0.80      0.92      0.86      1569
#           1       0.50      0.25      0.33       477
#
# avg / total       0.73      0.77      0.73      2046
# Feature ranking:
# 1. feature NU_QTD_VEZES_PROF_ESC (0.085746)
# 2. feature NU_IDADE_REFERENCIA_PROF (0.062368)
# 3. feature NU_MEDIA_TURMAS_NU_QTD_ALUNOS (0.045010)
# 4. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0 (0.038442)
# 5. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9 (0.029154)
# 6. feature CO_CLUSTER_PROF (0.028031)
# 7. feature FX_IDADE (0.026944)
# 8. feature NU_QTD_TURMAS_PROF_ESCOLA (0.024768)
# 9. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3 (0.021622)
# 10. feature NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS (0.021503)
# 11. feature NU_QTD_TURMAS_IN_TURNO_1 (0.020852)
# 12. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2 (0.020728)
# 13. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_7 (0.019969)
# 14. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1 (0.019720)
# 15. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4 (0.019478)
# 16. feature NU_FUNCIONARIOS_SCHL (0.018869)
# 17. feature NU_COMPUTADOR_SCHL (0.018301)
# 18. feature NU_QTD_TURMAS_IN_TURNO_0 (0.017581)
# 19. feature NU_PROP_DOM_ALUGADOS_SC_SCHL (0.017483)
# 20. feature NU_SOMA_QTD_DOMICILIOS_SC_SCHL (0.016551)
# 21. feature NU_PROP_FUNS_SALAS_UTZD_SCHL (0.015783)
# 22. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_8 (0.015651)
# 23. feature NU_QTD_SETORES_CENSITARIOS_SC_SCHL (0.014529)
# 24. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5 (0.014507)
# 25. feature NU_SOMA_QTD_PESSOAS_SC_SCHL (0.014296)
# 26. feature NU_PROP_DOM_CEDIDOS_SC_SCHL (0.014281)
# 27. feature NU_PROP_DOM_EM_AQUISICAO_SC_SCHL (0.013835)
# 28. feature NU_PROP_PSS_MULHERES_RSP_SC_SCHL (0.013656)
# 29. feature NU_PROP_CPU_SALAS_UTZD_SCHL (0.013565)
# 30. feature NU_MEDIANA_QTD_PESSOAS_SC_SCHL (0.013481)
# 31. feature NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SC_SCHL (0.013472)
# 32. feature NU_PROP_PSS_ABXO_12ANOS_SC_SCHL (0.013334)
# 33. feature NU_COMP_ALUNO_SCHL (0.012731)
# 34. feature NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SC_SCHL (0.012673)
# 35. feature NU_PROP_PSS_ACIMA_90ANOS_SC_SCHL (0.012191)
# 36. feature NU_MEDIANA_QTD_DOMICILIOS_SC_SCHL (0.012021)
# 37. feature NU_MEDIANA_RENDA_MEDIA_SC_SCHL (0.011990)
# 38. feature NU_COMP_ADMINISTRATIVO_SCHL (0.011854)
# 39. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_6 (0.011814)
# 40. feature NU_SALAS_EXISTENTES_SCHL (0.011470)
# 41. feature NU_PROP_PSS_ACIMA_65ANOS_SC_SCHL (0.011460)
# 42. feature NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SC_SCHL (0.010357)
# 43. feature NU_PROP_PSS_MULHERES_SC_SCHL (0.010092)
# 44. feature IN_TP_COR_RACA_BRANCA_PROF (0.009839)
# 45. feature IN_TP_COR_RACA_NAO_INFMD_PROF (0.009756)
# 46. feature IN_ESPECIALIZACAO_PROF (0.009453)
# 47. feature IN_NASCEU_DF_PROF (0.009401)
# 48. feature IN_TP_COR_RACA_PARDA_PROF (0.008910)
# 49. feature CO_CLUSTER_SCHL (0.004057)
# 50. feature IN_BIBLIOTECA_SCHL (0.004030)
# 51. feature IN_BANHEIRO_CHUVEIRO_SCHL (0.003537)
# 52. feature IN_PATIO_COBERTO_SCHL (0.003465)
# 53. feature IN_EQUIP_IMPRESSORA_MULT_SCHL (0.003110)
# 54. feature IN_QUADRA_ESPORTES_DESCOBERTA_SCHL (0.003093)
# 55. feature IN_LABORATORIO_CIENCIAS_SCHL (0.003005)
# 56. feature IN_ATIVIDADE_COMPLEMENTAR_SCHL (0.002965)
# 57. feature IN_EQUIP_FOTO_SCHL (0.002773)
# 58. feature IN_EQUIP_PARABOLICA_SCHL (0.002622)
# 59. feature IN_DESPENSA_SCHL (0.002607)
# 60. feature IN_DEPENDENCIAS_PNE_SCHL (0.002544)
# 61. feature IN_EQUIP_FAX_SCHL (0.002489)
# 62. feature IN_REFEITORIO_SCHL (0.002455)
# 63. feature IN_SALA_LEITURA_SCHL (0.002449)
# 64. feature IN_ALMOXARIFADO_SCHL (0.002409)
# 65. feature IN_AREA_VERDE_SCHL (0.002370)
# 66. feature IN_AEE_SCHL (0.002366)
# 67. feature IN_FINAL_SEMANA_SCHL (0.002331)
# 68. feature IN_LABORATORIO_INFORMATICA_SCHL (0.002309)
# 69. feature IN_EQUIP_VIDEOCASSETE_SCHL (0.002307)
# 70. feature IN_BANHEIRO_PNE_SCHL (0.002209)
# 71. feature IN_EQUIP_RETROPROJETOR_SCHL (0.002209)
# 72. feature IN_AUDITORIO_SCHL (0.002202)
# 73. feature IN_BANHEIRO_EI_SCHL (0.002169)
# 74. feature IN_SALA_ATENDIMENTO_ESPECIAL_SCHL (0.002111)
# 75. feature IN_PARQUE_INFANTIL_SCHL (0.001840)
# 76. feature IN_PATIO_DESCOBERTO_SCHL (0.001775)
# 77. feature IN_QUADRA_ESPORTES_SCHL (0.001756)
# 78. feature IN_QUADRA_ESPORTES_COBERTA_SCHL (0.001689)
# 79. feature IN_BIBLIOTECA_SALA_LEITURA_SCHL (0.001379)
# 80. feature IN_ESGOTO_FOSSA_SCHL (0.001165)
# 81. feature IN_ESGOTO_REDE_PUBLICA_SCHL (0.000680)
# Nao foi possivel mostrar o feature importance.
# The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import xgboost as xgb
#modelagem com xgboost
xgb_clf = xgb.XGBClassifier()
ft_xgb,_ = modelagem.processa_tudo(df_mod,tg='IN_SAIU_ESCOLA',vai_escalar=False,clf=xgb_clf)
# Out:
# /home/itsbarreto/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/itsbarreto/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/itsbarreto/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Base de TREINO
#              precision    recall  f1-score   support
#
#           0       0.82      0.96      0.88      4654
#           1       0.74      0.31      0.44      1483
#
# avg / total       0.80      0.81      0.78      6137
#
# Base de TESTE
#              precision    recall  f1-score   support
#
#           0       0.81      0.95      0.87      1569
#           1       0.62      0.25      0.36       477
#
# avg / total       0.76      0.79      0.75      2046
# Feature ranking:
# 1. feature NU_IDADE_REFERENCIA_PROF (0.092913)
# 2. feature NU_QTD_VEZES_PROF_ESC (0.092913)
# 3. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0 (0.048819)
# 4. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2 (0.040945)
# 5. feature NU_FUNCIONARIOS_SCHL (0.036220)
# 6. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4 (0.034646)
# 7. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_6 (0.034646)
# 8. feature NU_PROP_DOM_ALUGADOS_SC_SCHL (0.029921)
# 9. feature NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS (0.029921)
# 10. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9 (0.028346)
# 11. feature NU_PROP_DOM_EM_AQUISICAO_SC_SCHL (0.028346)
# 12. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5 (0.025197)
# 13. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_8 (0.025197)
# 14. feature NU_COMPUTADOR_SCHL (0.025197)
# 15. feature NU_MEDIA_TURMAS_NU_QTD_ALUNOS (0.023622)
# 16. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_7 (0.023622)
# 17. feature NU_SOMA_QTD_PESSOAS_SC_SCHL (0.023622)
# 18. feature NU_SOMA_QTD_DOMICILIOS_SC_SCHL (0.022047)
# 19. feature NU_QTD_TURMAS_PROF_ESCOLA (0.018898)
# 20. feature NU_MEDIANA_RENDA_MEDIA_SC_SCHL (0.017323)
# 21. feature NU_PROP_PSS_ACIMA_90ANOS_SC_SCHL (0.017323)
# 22. feature NU_COMP_ADMINISTRATIVO_SCHL (0.015748)
# 23. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1 (0.015748)
# 24. feature NU_QTD_SETORES_CENSITARIOS_SC_SCHL (0.015748)
# 25. feature NU_SALAS_EXISTENTES_SCHL (0.015748)
# 26. feature NU_MEDIANA_QTD_DOMICILIOS_SC_SCHL (0.015748)
# 27. feature NU_PROP_DOM_CEDIDOS_SC_SCHL (0.015748)
# 28. feature NU_MEDIANA_QTD_PESSOAS_SC_SCHL (0.014173)
# 29. feature NU_PROP_PSS_ACIMA_65ANOS_SC_SCHL (0.014173)
# 30. feature NU_PROP_CPU_SALAS_UTZD_SCHL (0.012598)
# 31. feature NU_QTD_TURMAS_IN_TURNO_1 (0.012598)
# 32. feature CO_CLUSTER_PROF (0.012598)
# 33. feature CO_CLUSTER_SCHL (0.009449)
# 34. feature NU_MEDIA_DISTANCIA_ESCOLA_SETOR_SC_SCHL (0.009449)
# 35. feature NU_QTD_TURMAS_IN_TURNO_0 (0.007874)
# 36. feature NU_PROP_PSS_MULHERES_RSP_SC_SCHL (0.007874)
# 37. feature NU_PROP_DOM_RENDA_PERCAPITA_ACIMA_5SM_SC_SCHL (0.007874)
# 38. feature NU_COMP_ALUNO_SCHL (0.007874)
# 39. feature NU_PROP_FUNS_SALAS_UTZD_SCHL (0.006299)
# 40. feature IN_PATIO_COBERTO_SCHL (0.006299)
# 41. feature IN_BANHEIRO_PNE_SCHL (0.006299)
# 42. feature NU_PROP_PSS_ABXO_12ANOS_SC_SCHL (0.004724)
# 43. feature IN_EQUIP_FOTO_SCHL (0.004724)
# 44. feature IN_REFEITORIO_SCHL (0.004724)
# 45. feature IN_PARQUE_INFANTIL_SCHL (0.004724)
# 46. feature IN_NASCEU_DF_PROF (0.004724)
# 47. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3 (0.003150)
# 48. feature NU_PROP_DOM_RENDA_PERCAPITA_ABXO_1SM_SC_SCHL (0.003150)
# 49. feature IN_BANHEIRO_CHUVEIRO_SCHL (0.003150)
# 50. feature IN_EQUIP_VIDEOCASSETE_SCHL (0.001575)
# 51. feature IN_LABORATORIO_CIENCIAS_SCHL (0.001575)
# 52. feature IN_SALA_ATENDIMENTO_ESPECIAL_SCHL (0.001575)
# 53. feature IN_TP_COR_RACA_BRANCA_PROF (0.001575)
# 54. feature IN_ESPECIALIZACAO_PROF (0.001575)
# 55. feature IN_FINAL_SEMANA_SCHL (0.001575)
# 56. feature IN_SALA_LEITURA_SCHL (0.001575)
# 57. feature IN_EQUIP_PARABOLICA_SCHL (0.001575)
# 58. feature IN_DEPENDENCIAS_PNE_SCHL (0.001575)
# 59. feature IN_EQUIP_IMPRESSORA_MULT_SCHL (0.001575)
# 60. feature IN_EQUIP_RETROPROJETOR_SCHL (0.001575)
# 61. feature IN_TP_COR_RACA_NAO_INFMD_PROF (0.000000)
# 62. feature FX_IDADE (0.000000)
# 63. feature IN_TP_COR_RACA_PARDA_PROF (0.000000)
# 64. feature IN_DESPENSA_SCHL (0.000000)
# 65. feature NU_PROP_PSS_MULHERES_SC_SCHL (0.000000)
# 66. feature IN_ATIVIDADE_COMPLEMENTAR_SCHL (0.000000)
# 67. feature IN_AEE_SCHL (0.000000)
# 68. feature IN_EQUIP_FAX_SCHL (0.000000)
# 69. feature IN_AREA_VERDE_SCHL (0.000000)
# 70. feature IN_PATIO_DESCOBERTO_SCHL (0.000000)
# 71. feature IN_AUDITORIO_SCHL (0.000000)
# 72. feature IN_BANHEIRO_EI_SCHL (0.000000)
# 73. feature IN_ESGOTO_REDE_PUBLICA_SCHL (0.000000)
# 74. feature IN_BIBLIOTECA_SALA_LEITURA_SCHL (0.000000)
# 75. feature IN_BIBLIOTECA_SCHL (0.000000)
# 76. feature IN_QUADRA_ESPORTES_SCHL (0.000000)
# 77. feature IN_QUADRA_ESPORTES_DESCOBERTA_SCHL (0.000000)
# 78. feature IN_QUADRA_ESPORTES_COBERTA_SCHL (0.000000)
# 79. feature IN_LABORATORIO_INFORMATICA_SCHL (0.000000)
# 80. feature IN_ESGOTO_FOSSA_SCHL (0.000000)
# 81. feature IN_ALMOXARIFADO_SCHL (0.000000)

# %% [markdown]
# #### Observações interessantes:
#
# Mesmo havendo um claro _overfit_ um AUC de 70 e 76,6 para o RandomForest e para o XGBoost respectivamente, são dados interessantes uma vez que os modelos estão sem hiperparametrização.
#
# Vamos executar os algoritmos só com as 15 _features_ mais significativas de cada modelo para então compará-las.

# %%
QTD_FEATURES_MAIS_IMPORTANTES = 15

# %%
#seleciona as 15 features mais importantes de cada modelo.
cols_imp_rf = ft_rf[:QTD_FEATURES_MAIS_IMPORTANTES] + ['IN_SAIU_ESCOLA']
#modelagem RandomForest
ft_15_rf,_ = modelagem.processa_tudo(df_mod[cols_imp_rf],tg='IN_SAIU_ESCOLA',vai_escalar=False);
# Out:
# /home/itsbarreto/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Base de TREINO
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      4654
#           1       0.99      0.92      0.95      1483
#
# avg / total       0.98      0.98      0.98      6137
#
# Base de TESTE
#              precision    recall  f1-score   support
#
#           0       0.80      0.92      0.86      1569
#           1       0.47      0.23      0.31       477
#
# avg / total       0.72      0.76      0.73      2046
# Feature ranking:
# 1. feature NU_QTD_VEZES_PROF_ESC (0.115116)
# 2. feature NU_IDADE_REFERENCIA_PROF (0.113479)
# 3. feature NU_MEDIA_TURMAS_NU_QTD_ALUNOS (0.108628)
# 4. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9 (0.084828)
# 5. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0 (0.082495)
# 6. feature CO_CLUSTER_PROF (0.068186)
# 7. feature NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS (0.064226)
# 8. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_3 (0.062940)
# 9. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_1 (0.050463)
# 10. feature NU_QTD_TURMAS_PROF_ESCOLA (0.048721)
# 11. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2 (0.047464)
# 12. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_7 (0.045754)
# 13. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4 (0.043182)
# 14. feature NU_QTD_TURMAS_IN_TURNO_1 (0.034229)
# 15. feature FX_IDADE (0.030289)
# Nao foi possivel plotar o feature importance.
# The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
cols_imp_xgb = ft_xgb[:QTD_FEATURES_MAIS_IMPORTANTES] + ['IN_SAIU_ESCOLA']
#reinicializa o classificador do xgboost
xgb_clf = xgb.XGBClassifier()
#modelagem RandomForest
ft_15_xgb,_ = modelagem.processa_tudo(df_mod[cols_imp_xgb],tg='IN_SAIU_ESCOLA',vai_escalar=False,clf=xgb_clf);
# Out:
# /home/itsbarreto/.local/lib/python3.6/site-packages/numpy/core/_methods.py:32: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims)
# /home/itsbarreto/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/itsbarreto/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Base de TREINO
#              precision    recall  f1-score   support
#
#           0       0.81      0.96      0.88      4654
#           1       0.72      0.30      0.42      1483
#
# avg / total       0.79      0.80      0.77      6137
#
# Base de TESTE
#              precision    recall  f1-score   support
#
#           0       0.81      0.95      0.87      1569
#           1       0.62      0.25      0.36       477
#
# avg / total       0.76      0.79      0.75      2046
# Feature ranking:
# 1. feature NU_IDADE_REFERENCIA_PROF (0.126023)
# 2. feature NU_QTD_VEZES_PROF_ESC (0.108020)
# 3. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_0 (0.088380)
# 4. feature NU_PROP_DOM_ALUGADOS_SC_SCHL (0.073650)
# 5. feature NU_PROP_DOM_EM_AQUISICAO_SC_SCHL (0.072013)
# 6. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_2 (0.072013)
# 7. feature NU_MEDIA_TURMAS_NU_QTD_ALUNOS (0.070376)
# 8. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_8 (0.067103)
# 9. feature NU_COMPUTADOR_SCHL (0.063830)
# 10. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_9 (0.052373)
# 11. feature NU_MEDIA_TURMAS_NU_QTD_DISCIPLINAS (0.052373)
# 12. feature NU_FUNCIONARIOS_SCHL (0.052373)
# 13. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_6 (0.039280)
# 14. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_4 (0.032733)
# 15. feature NU_MEDIA_TURMAS_NU_PROP_ALUNOS_ROTULO_5 (0.029460)

# %%
#conta quantas features são iguais
ttl_coincidencias = np.sum([f in ft_15_xgb for f in ft_15_rf])
print('Houve .2f % de coincidências.' %(ttl_coincidencias/15 * 100))
# Out:
# Houve .2f  53e coincidências.

# %% [markdown]
# #### Observações interessantes:
#
# Conseguimos manter um AUC bastante próximo do anterior.
